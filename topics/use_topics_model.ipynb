# %%
# !pip install openai_async -q
# Out:
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import ast
import os
import re
import openai
from typing import List, Set, Tuple

import aiohttp 
import asyncio
import openai_async
from openai.error import RateLimitError, InvalidRequestError

# %%
# openai.api_key = ...

# %% [markdown]
# ### I'll use the fine-tuned openai `ada` model to extract topics from the GCNs. But firstly I will measure the model's metrics on the labelled Atel data (a fraction of the training data).

# %%
atel_df = pd.read_csv("atel_with_topics.csv", index_col=0)
atel_df['topics'] = atel_df['topics'].apply(lambda x: x.split(','))

# %%
def use_topics_model(text):
    
    PROMPT = f"""
    {text}
    \n\n###\n\n
    """
    
    resp = openai.Completion.create(
        model="ada:ft-pai-2023-05-16-20-18-46",
        prompt=PROMPT)
    
    return [x.strip() for x in resp['choices'][0]['text'].replace("###", ',').split(',') if x.strip()]


def calculate_precision_recall_f1(true: List[Set[str]], pred: List[Set[str]]):
    true_positives = 0
    false_positives = 0
    false_negatives = 0

    for y_true, y_pred in zip(true, pred):
        true_positives += len(y_true.intersection(y_pred))
        false_positives += len(y_pred - y_true)
        false_negatives += len(y_true - y_pred)

    precision = true_positives / (true_positives + false_positives)
    recall = true_positives / (true_positives + false_negatives)
    f1 = 2 * (precision * recall) / (precision + recall)

    return precision, recall, f1

# %%
sample_atel_df = atel_df.sample(frac=0.3)
len(sample_atel_df)
# Out:
# 4750

# %%
sample_atel_df['predicted_topics'] = sample_atel_df.body_clean.apply(use_topics_model)

# %%
# clean both topics

# %%
sample_atel_df['predicted_topics'] = sample_atel_df['predicted_topics'].apply(lambda x: list(set(x)))\
    .apply(lambda x: [y.replace('\n', '').strip() for y in x if y!='#' and len(y.split(' '))<=3])

# %%
sample_atel_df['topics'] = sample_atel_df['topics'].apply(lambda x: [y.replace('\n', '').strip() for y in x])

# %%
sample_atel_df.head()
# Out:
#                                                            topics  \
# telegram_index
# 1781_atel       [x-ray, gamma ray, request for observations, t...
# 3493_atel       [x-ray, gamma ray, neutron star, soft gamma-ra...
# 14725_atel                 [x-ray, binary, black hole, transient]
# 4176_atel                   [x-ray, gamma ray, binary, transient]
# 2256_atel                  [optical, gamma ray, gev, agn, quasar]
#
#                                                        body_clean  \
# telegram_index
# 1781_atel       the ibis isgri instrument aboard integral disc...
# 3493_atel       using 1046 xrt photon counting mode data 1 uvo...
# 14725_atel      the nicer telescope followed recently reported...
# 4176_atel       swift observed new outburst sfxt ax j1841.0-05...
# 2256_atel       the large area telescope lat one two instrumen...
#
#                                                  predicted_topics
# telegram_index
# 1781_atel       [binary, black hole, x-ray, cataclysmic, gamma...
# 3493_atel                    [methods, transient, x-ray, optical]
# 14725_atel                 [transient, gev, tev, black hole, vhe]
# 4176_atel                   [transient, x-ray, binary, gamma ray]
# 2256_atel       [quasar, gev, blazar, request for observations...

# %%
topics = sample_atel_df['topics'].apply(set).values.tolist()
pred_topics = sample_atel_df['predicted_topics'].apply(set).values.tolist()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'predicted_topics'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/lq/lkt2bk2975nd1gbswlb64k5r0000gp/T/ipykernel_41543/853488043.py in <module>
#       1 topics = sample_atel_df['topics'].apply(set).values.tolist()
# ----> 2 pred_topics = sample_atel_df['predicted_topics'].apply(set).values.tolist()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'predicted_topics'

# %%
 # it is bearable I'd say. Consider that the training costed only 9$ and this is the cheapest openai's model
calculate_precision_recall_f1(topics, pred_topics)
# Out:
# (0.6310580935059378, 0.6783783783783783, 0.6538632080700587)

# %% [markdown]
# ### Get them topics for all GCNs
# Make async calls so speed things up

# %%
clean_bodies = pd.read_csv("../word2vec/clean_bodies.csv", index_col=0)

# %%
gcn_df = clean_bodies[clean_bodies.index.str.endswith('gcn')]

# %%
gcn_bodies = gcn_df['body_clean'].values

# %%
SEMAPHORE_LIMIT = 50
TIMEOUT = 120
LLM_MODEL = 'ada:ft-pai-2023-05-16-20-18-46'


async def gather_with_concurrency(n: int, *tasks):
    semaphore = asyncio.Semaphore(n)

    async def sem_task(task):
        async with semaphore:
            return await task

    return await asyncio.gather(*(sem_task(task) for task in tasks))


async def call_one(text: str, i: int) -> str:
    print(f'Calling for doc #{i}')

    await asyncio.sleep(0.5)
    prompt = f"""
    {text}
    \n\n###\n\n
    """
    payload = {"model": LLM_MODEL, "prompt": prompt}

    response = await openai_async.complete(openai.api_key, payload=payload, timeout=TIMEOUT)

    try:
        return [x.strip() for x in response.json()['choices'][0]['text'].replace("###", ',').split(',') if x.strip()]      
        
    except:
        if response.json()['error']['type'] == "invalid_request_error":
            print(f'Token limit for doc #{i} exceeded, reducing the prompt size.')
            text = text[:int(len(text)*0.9)]
            return await call_one(text, i)
        
        elif response.json()['error']['type'] == "rate_limit_error":
            print(f'Request limit exceeded, sleeping and waiting to re-call for doc #{i}')
            await asyncio.sleep(5)
            return await call_one(text, i)
        
        else:
            return []
    
async def call_all(texts: List[str]): 
    tasks = []
    for i, text in enumerate(texts):
          tasks.append(call_one(text, i))
    return await gather_with_concurrency(SEMAPHORE_LIMIT, *tasks)

# %%
all_topics = []

texts = gcn_bodies

topics = await call_all(texts)
all_topics.extend(topics)
# Out:
# Calling for doc #0
# Calling for doc #1
# Calling for doc #2
# Calling for doc #3
# Calling for doc #4
# Calling for doc #5
# Calling for doc #6
# Calling for doc #7
# Calling for doc #8
# Calling for doc #9
# Calling for doc #10
# Calling for doc #11
# Calling for doc #12
# Calling for doc #13
# Calling for doc #14
# Calling for doc #15
# Calling for doc #16
# Calling for doc #17
# Calling for doc #18
# Calling for doc #19
# Calling for doc #20
# Calling for doc #21
# Calling for doc #22
# Calling for doc #23
# Calling for doc #24
# Calling for doc #25
# Calling for doc #26
# Calling for doc #27
# Calling for doc #28
# Calling for doc #29
# Calling for doc #30
# Calling for doc #31
# Calling for doc #32
# Calling for doc #33
# Calling for doc #34
# Calling for doc #35
# Calling for doc #36
# Calling for doc #37
# Calling for doc #38
# Calling for doc #39
# Calling for doc #40
# Calling for doc #41
# Calling for doc #42
# Calling for doc #43
# Calling for doc #44
# Calling for doc #45
# Calling for doc #46
# Calling for doc #47
# Calling for doc #48
# Calling for doc #49
# Calling for doc #50
# Calling for doc #51
# Calling for doc #52
# Calling for doc #53
# Calling for doc #54
# Calling for doc #55
# Calling for doc #56
# Calling for doc #57
# Calling for doc #58
# Calling for doc #59
# Calling for doc #60
# Calling for doc #61
# Calling for doc #62
# Calling for doc #63
# Calling for doc #64
# Calling for doc #65
# Calling for doc #66
# Calling for doc #67
# Calling for doc #68
# Calling for doc #69
# Calling for doc #70
# Calling for doc #71
# Calling for doc #72
# Calling for doc #73
# Calling for doc #74
# Calling for doc #75
# Calling for doc #76
# Calling for doc #77
# Calling for doc #78
# Calling for doc #79
# Calling for doc #80
# Calling for doc #81
# Calling for doc #82
# Calling for doc #83
# Calling for doc #84
# Calling for doc #85
# Calling for doc #86
# Calling for doc #87
# Calling for doc #88
# Calling for doc #89
# Calling for doc #90
# Calling for doc #91
# Calling for doc #92
# Calling for doc #93
# Calling for doc #94
# Calling for doc #95
# Calling for doc #96
# Calling for doc #97
# Calling for doc #98
# Calling for doc #99
# Calling for doc #100
# Calling for doc #101
# Calling for doc #102
# Calling for doc #103
# Calling for doc #104
# Calling for doc #105
# Calling for doc #106
# Calling for doc #107
# Calling for doc #108
# Calling for doc #109
# Calling for doc #110
# Calling for doc #111
# Calling for doc #112
# Calling for doc #113
# Calling for doc #114
# Calling for doc #115
# Calling for doc #116
# Calling for doc #117
# Calling for doc #118
# Calling for doc #119
# Calling for doc #120
# Calling for doc #121
# Calling for doc #122
# Calling for doc #123
# Calling for doc #124
# Calling for doc #125
# Calling for doc #126
# Calling for doc #127
# Calling for doc #128
# Calling for doc #129
# Calling for doc #130
# Calling for doc #131
# Calling for doc #132
# Calling for doc #133
# Calling for doc #134
# Calling for doc #135
# Calling for doc #136
# Calling for doc #137
# Calling for doc #138
# Calling for doc #139
# Calling for doc #140
# Calling for doc #141
# Calling for doc #142
# Calling for doc #143
# Calling for doc #144
# Calling for doc #145
# Calling for doc #146
# Calling for doc #147
# Calling for doc #148
# Calling for doc #149
# Calling for doc #150
# Calling for doc #151
# Calling for doc #152
# Calling for doc #153
# Calling for doc #154
# Calling for doc #155
# Calling for doc #156
# Calling for doc #157
# Calling for doc #158
# Calling for doc #159
# Calling for doc #160
# Calling for doc #161
# Calling for doc #162
# Calling for doc #163
# Calling for doc #164
# Calling for doc #165
# Calling for doc #166
# Calling for doc #167
# Calling for doc #168
# Calling for doc #169
# Calling for doc #170
# Calling for doc #171
# Calling for doc #172
# Calling for doc #173
# Calling for doc #174
# Calling for doc #175
# Calling for doc #176
# Calling for doc #177
# Calling for doc #178
# Calling for doc #179
# Calling for doc #180
# Calling for doc #181
# Calling for doc #182
# Calling for doc #183
# Calling for doc #184
# Calling for doc #185
# Calling for doc #186
# Calling for doc #187
# Calling for doc #188
# Calling for doc #189
# Calling for doc #190
# Calling for doc #191
# Calling for doc #192
# Calling for doc #193
# Calling for doc #194
# Calling for doc #195
# Calling for doc #196
# Calling for doc #197
# Calling for doc #198
# Calling for doc #199
# Calling for doc #200
# Calling for doc #201
# Calling for doc #202
# Calling for doc #203
# Calling for doc #204
# Calling for doc #205
# Calling for doc #206
# Calling for doc #207
# Calling for doc #208
# Calling for doc #209
# Calling for doc #210
# Calling for doc #211
# Calling for doc #212
# Calling for doc #213
# Calling for doc #214
# Calling for doc #215
# Calling for doc #216
# Calling for doc #217
# Calling for doc #218
# Calling for doc #219
# Calling for doc #220
# Calling for doc #221
# Calling for doc #222
# Calling for doc #223
# Calling for doc #224
# Calling for doc #225
# Calling for doc #226
# Calling for doc #227
# Calling for doc #228
# Calling for doc #229
# Calling for doc #230
# Calling for doc #231
# Calling for doc #232
# Calling for doc #233
# Calling for doc #234
# Calling for doc #235
# Calling for doc #236
# Calling for doc #237
# Calling for doc #238
# Calling for doc #239
# Calling for doc #240
# Calling for doc #241
# Calling for doc #242
# Calling for doc #243
# Calling for doc #244
# Calling for doc #245
# Calling for doc #246
# Calling for doc #247
# Calling for doc #248
# Calling for doc #249
# Calling for doc #250
# Calling for doc #251
# Calling for doc #252
# Calling for doc #253
# Calling for doc #254
# Calling for doc #255
# Calling for doc #256
# Calling for doc #257
# Calling for doc #258
# Calling for doc #259
# Calling for doc #260
# Calling for doc #261
# Calling for doc #262
# Calling for doc #263
# Calling for doc #264
# Calling for doc #265
# Calling for doc #266
# Calling for doc #267
# Calling for doc #268
# Calling for doc #269
# Calling for doc #270
# Calling for doc #271
# Calling for doc #272
# Calling for doc #273
# Calling for doc #274
# Calling for doc #275
# Calling for doc #276
# Calling for doc #277
# Calling for doc #278
# Calling for doc #279
# Calling for doc #280
# Calling for doc #281
# Calling for doc #282
# Calling for doc #283
# Calling for doc #284
# Calling for doc #285
# Calling for doc #286
# Calling for doc #287
# Calling for doc #288
# Calling for doc #289
# Calling for doc #290
# Calling for doc #291
# Calling for doc #292
# Calling for doc #293
# Calling for doc #294
# Calling for doc #295
# Calling for doc #296
# Calling for doc #297
# Calling for doc #298
# Calling for doc #299
# Calling for doc #300
# Calling for doc #301
# Calling for doc #302
# Calling for doc #303
# Calling for doc #304
# Calling for doc #305
# Calling for doc #306
# Calling for doc #307
# Calling for doc #308
# Calling for doc #309
# Calling for doc #310
# Calling for doc #311
# Calling for doc #312
# Calling for doc #313
# Calling for doc #314
# Calling for doc #315
# Calling for doc #316
# Calling for doc #317
# Calling for doc #318
# Calling for doc #319
# Calling for doc #320
# Calling for doc #321
# Calling for doc #322
# Calling for doc #323
# Calling for doc #324
# Calling for doc #325
# Calling for doc #326
# Calling for doc #327
# Calling for doc #328
# Calling for doc #329
# Calling for doc #330
# Calling for doc #331
# Calling for doc #332
# Calling for doc #333
# Calling for doc #334
# Calling for doc #335
# Calling for doc #336
# Calling for doc #337
# Calling for doc #338
# Calling for doc #339
# Calling for doc #340
# Calling for doc #341
# Calling for doc #342
# Calling for doc #343
# Calling for doc #344
# Calling for doc #345
# Calling for doc #346
# Calling for doc #347
# Calling for doc #348
# Calling for doc #349
# Calling for doc #350
# Calling for doc #351
# Calling for doc #352
# Calling for doc #353
# Calling for doc #354
# Calling for doc #355
# Calling for doc #356
# Calling for doc #357
# Calling for doc #358
# Calling for doc #359
# Calling for doc #360
# Calling for doc #361
# Calling for doc #362
# Calling for doc #363
# Calling for doc #364
# Calling for doc #365
# Calling for doc #366
# Calling for doc #367
# Calling for doc #368
# Calling for doc #369
# Calling for doc #370
# Calling for doc #371
# Calling for doc #372
# Calling for doc #373
# Calling for doc #374
# Calling for doc #375
# Calling for doc #376
# Calling for doc #377
# Calling for doc #378
# Calling for doc #379
# Calling for doc #380
# Calling for doc #381
# Calling for doc #382
# Calling for doc #383
# Calling for doc #384
# Calling for doc #385
# Calling for doc #386
# Calling for doc #387
# Calling for doc #388
# Calling for doc #389
# Calling for doc #390
# Calling for doc #391
# Calling for doc #392
# Calling for doc #393
# Calling for doc #394
# Calling for doc #395
# Calling for doc #396
# Calling for doc #397
# Calling for doc #398
# Calling for doc #399
# Calling for doc #400
# Calling for doc #401
# Calling for doc #402
# Calling for doc #403
# Calling for doc #404
# Calling for doc #405
# Calling for doc #406
# Calling for doc #407
# Calling for doc #408
# Calling for doc #409
# Calling for doc #410
# Calling for doc #411
# Calling for doc #412
# Calling for doc #413
# Calling for doc #414
# Calling for doc #415
# Calling for doc #416
# Calling for doc #417
# Calling for doc #418
# Calling for doc #419
# Calling for doc #420
# Calling for doc #421
# Calling for doc #422
# Calling for doc #423
# Calling for doc #424
# Calling for doc #425
# Calling for doc #426
# Calling for doc #427
# Calling for doc #428
# Calling for doc #429
# Calling for doc #430
# Calling for doc #431
# Calling for doc #432
# Calling for doc #433
# Calling for doc #434
# Calling for doc #435
# Calling for doc #436
# Calling for doc #437
# Calling for doc #438
# Calling for doc #439
# Calling for doc #440
# Calling for doc #441
# Calling for doc #442
# Calling for doc #443
# Calling for doc #444
# Calling for doc #445
# Calling for doc #446
# Calling for doc #447
# Calling for doc #448
# Calling for doc #449
# Calling for doc #450
# Calling for doc #451
# Calling for doc #452
# Calling for doc #453
# Calling for doc #454
# Calling for doc #455
# Calling for doc #456
# Calling for doc #457
# Calling for doc #458
# Calling for doc #459
# Calling for doc #460
# Calling for doc #461
# Calling for doc #462
# Calling for doc #463
# Calling for doc #464
# Calling for doc #465
# Calling for doc #466
# Calling for doc #467
# Calling for doc #468
# Calling for doc #469
# Calling for doc #470
# Calling for doc #471
# Calling for doc #472
# Calling for doc #473
# Calling for doc #474
# Calling for doc #475
# Calling for doc #476
# Calling for doc #477
# Calling for doc #478
# Calling for doc #479
# Calling for doc #480
# Calling for doc #481
# Calling for doc #482
# Calling for doc #483
# Calling for doc #484
# Calling for doc #485
# Calling for doc #486
# Calling for doc #487
# Calling for doc #488
# Calling for doc #489
# Calling for doc #490
# Calling for doc #491
# Calling for doc #492
# Calling for doc #493
# Calling for doc #494
# Calling for doc #495
# Calling for doc #496
# Calling for doc #497
# Calling for doc #498
# Calling for doc #499
# Calling for doc #500
# Calling for doc #501
# Calling for doc #502
# Calling for doc #503
# Calling for doc #504
# Calling for doc #505
# Calling for doc #506
# Calling for doc #507
# Calling for doc #508
# Calling for doc #509
# Calling for doc #510
# Calling for doc #511
# Calling for doc #512
# Calling for doc #513
# Calling for doc #514
# Calling for doc #515
# Calling for doc #516
# Calling for doc #517
# Calling for doc #518
# Calling for doc #519
# Calling for doc #520
# Calling for doc #521
# Calling for doc #522
# Calling for doc #523
# Calling for doc #524
# Calling for doc #525
# Calling for doc #526
# Calling for doc #527
# Calling for doc #528
# Calling for doc #529
# Calling for doc #530
# Calling for doc #531
# Calling for doc #532
# Calling for doc #533
# Calling for doc #534
# Calling for doc #535
# Calling for doc #536
# Calling for doc #537
# Calling for doc #538
# Calling for doc #539
# Calling for doc #540
# Calling for doc #541
# Calling for doc #542
# Calling for doc #543
# Calling for doc #544
# Calling for doc #545
# Calling for doc #546
# Calling for doc #547
# Calling for doc #548
# Calling for doc #549
# Calling for doc #550
# Calling for doc #551
# Calling for doc #552
# Calling for doc #553
# Calling for doc #554
# Calling for doc #555
# Calling for doc #556
# Calling for doc #557
# Calling for doc #558
# Calling for doc #559
# Calling for doc #560
# Calling for doc #561
# Calling for doc #562
# Calling for doc #563
# Calling for doc #564
# Calling for doc #565
# Calling for doc #566
# Calling for doc #567
# Calling for doc #568
# Calling for doc #569
# Calling for doc #570
# Calling for doc #571
# Calling for doc #572
# Calling for doc #573
# Calling for doc #574
# Calling for doc #575
# Calling for doc #576
# Calling for doc #577
# Calling for doc #578
# Calling for doc #579
# Calling for doc #580
# Calling for doc #581
# Calling for doc #582
# Calling for doc #583
# Calling for doc #584
# Calling for doc #585
# Calling for doc #586
# Calling for doc #587
# Calling for doc #588
# Calling for doc #589
# Calling for doc #590
# Calling for doc #591
# Calling for doc #592
# Calling for doc #593
# Calling for doc #594
# Calling for doc #595
# Calling for doc #596
# Calling for doc #597
# Calling for doc #598
# Calling for doc #599
# Calling for doc #600
# Calling for doc #601
# Calling for doc #602
# Calling for doc #603
# Calling for doc #604
# Calling for doc #605
# Calling for doc #606
# Calling for doc #607
# Calling for doc #608
# Calling for doc #609
# Calling for doc #610
# Calling for doc #611
# Calling for doc #612
# Calling for doc #613
# Calling for doc #614
# Calling for doc #615
# Calling for doc #616
# Calling for doc #617
# Calling for doc #618
# Calling for doc #619
# Calling for doc #620
# Calling for doc #621
# Calling for doc #622
# Calling for doc #623
# Calling for doc #624
# Calling for doc #625
# Calling for doc #626
# Calling for doc #627
# Calling for doc #628
# Calling for doc #629
# Calling for doc #630
# Calling for doc #631
# Calling for doc #632
# Calling for doc #633
# Calling for doc #634
# Calling for doc #635
# Calling for doc #636
# Calling for doc #637
# Calling for doc #638
# Calling for doc #639
# Calling for doc #640
# Calling for doc #641
# Calling for doc #642
# Calling for doc #643
# Calling for doc #644
# Calling for doc #645
# Calling for doc #646
# Calling for doc #647
# Calling for doc #648
# Calling for doc #649
# Calling for doc #650
# Calling for doc #651
# Calling for doc #652
# Calling for doc #653
# Calling for doc #654
# Calling for doc #655
# Calling for doc #656
# Calling for doc #657
# Calling for doc #658
# Calling for doc #659
# Calling for doc #660
# Calling for doc #661
# Calling for doc #662
# Calling for doc #663
# Calling for doc #664
# Calling for doc #665
# Calling for doc #666
# Calling for doc #667
# Calling for doc #668
# Calling for doc #669
# Calling for doc #670
# Calling for doc #671
# Calling for doc #672
# Calling for doc #673
# Calling for doc #674
# Calling for doc #675
# Calling for doc #676
# Calling for doc #677
# Calling for doc #678
# Calling for doc #679
# Calling for doc #680
# Calling for doc #681
# Calling for doc #682
# Calling for doc #683
# Calling for doc #684
# Calling for doc #685
# Calling for doc #686
# Calling for doc #687
# Calling for doc #688
# Calling for doc #689
# Calling for doc #690
# Calling for doc #691
# Calling for doc #692
# Calling for doc #693
# Calling for doc #694
# Calling for doc #695
# Calling for doc #696
# Calling for doc #697
# Calling for doc #698
# Calling for doc #699
# Calling for doc #700
# Calling for doc #701
# Calling for doc #702
# Calling for doc #703
# Calling for doc #704
# Calling for doc #705
# Calling for doc #706
# Calling for doc #707
# Calling for doc #708
# Calling for doc #709
# Calling for doc #710
# Calling for doc #711
# Calling for doc #712
# Calling for doc #713
# Calling for doc #714
# Calling for doc #715
# Calling for doc #716
# Calling for doc #717
# Calling for doc #718
# Calling for doc #719
# Calling for doc #720
# Calling for doc #721
# Calling for doc #722
# Calling for doc #723
# Calling for doc #724
# Calling for doc #725
# Calling for doc #726
# Calling for doc #727
# Calling for doc #728
# Calling for doc #729
# Calling for doc #730
# Calling for doc #731
# Calling for doc #732
# Calling for doc #733
# Calling for doc #734
# Calling for doc #735
# Calling for doc #736
# Calling for doc #737
# Calling for doc #738
# Calling for doc #739
# Calling for doc #740
# Calling for doc #741
# Calling for doc #742
# Calling for doc #743
# Calling for doc #744
# Calling for doc #745
# Calling for doc #746
# Calling for doc #747
# Calling for doc #748
# Calling for doc #749
# Calling for doc #750
# Calling for doc #751
# Calling for doc #752
# Calling for doc #753
# Calling for doc #754
# Calling for doc #755
# Calling for doc #756
# Calling for doc #757
# Calling for doc #758
# Calling for doc #759
# Calling for doc #760
# Calling for doc #761
# Calling for doc #762
# Calling for doc #763
# Calling for doc #764
# Calling for doc #765
# Calling for doc #766
# Calling for doc #767
# Calling for doc #768
# Calling for doc #769
# Calling for doc #770
# Calling for doc #771
# Calling for doc #772
# Calling for doc #773
# Calling for doc #774
# Calling for doc #775
# Calling for doc #776
# Calling for doc #777
# Calling for doc #778
# Calling for doc #779
# Calling for doc #780
# Calling for doc #781
# Calling for doc #782
# Calling for doc #783
# Calling for doc #784
# Calling for doc #785
# Calling for doc #786
# Calling for doc #787
# Calling for doc #788
# Calling for doc #789
# Calling for doc #790
# Calling for doc #791
# Calling for doc #792
# Calling for doc #793
# Calling for doc #794
# Calling for doc #795
# Calling for doc #796
# Calling for doc #797
# Calling for doc #798
# Calling for doc #799
# Calling for doc #800
# Calling for doc #801
# Calling for doc #802
# Calling for doc #803
# Calling for doc #804
# Calling for doc #805
# Calling for doc #806
# Calling for doc #807
# Calling for doc #808
# Calling for doc #809
# Calling for doc #810
# Calling for doc #811
# Calling for doc #812
# Calling for doc #813
# Calling for doc #814
# Calling for doc #815
# Calling for doc #816
# Calling for doc #817
# Calling for doc #818
# Calling for doc #819
# Calling for doc #820
# Calling for doc #821
# Calling for doc #822
# Calling for doc #823
# Calling for doc #824
# Calling for doc #825
# Calling for doc #826
# Calling for doc #827
# Calling for doc #828
# Calling for doc #829
# Calling for doc #830
# Calling for doc #831
# Calling for doc #832
# Calling for doc #833
# Calling for doc #834
# Calling for doc #835
# Calling for doc #836
# Calling for doc #837
# Calling for doc #838
# Calling for doc #839
# Calling for doc #840
# Calling for doc #841
# Calling for doc #842
# Calling for doc #843
# Calling for doc #844
# Calling for doc #845
# Calling for doc #846
# Calling for doc #847
# Calling for doc #848
# Calling for doc #849
# Calling for doc #850
# Calling for doc #851
# Calling for doc #852
# Calling for doc #853
# Calling for doc #854
# Calling for doc #855
# Calling for doc #856
# Calling for doc #857
# Calling for doc #858
# Calling for doc #859
# Calling for doc #860
# Calling for doc #861
# Calling for doc #862
# Calling for doc #863
# Calling for doc #864
# Calling for doc #865
# Calling for doc #866
# Calling for doc #867
# Calling for doc #868
# Calling for doc #869
# Calling for doc #870
# Calling for doc #871
# Calling for doc #872
# Calling for doc #873
# Calling for doc #874
# Calling for doc #875
# Calling for doc #876
# Calling for doc #877
# Calling for doc #878
# Calling for doc #879
# Calling for doc #880
# Calling for doc #881
# Calling for doc #882
# Calling for doc #883
# Calling for doc #884
# Calling for doc #885
# Calling for doc #886
# Calling for doc #887
# Calling for doc #888
# Calling for doc #889
# Calling for doc #890
# Calling for doc #891
# Calling for doc #892
# Calling for doc #893
# Calling for doc #894
# Calling for doc #895
# Calling for doc #896
# Calling for doc #897
# Calling for doc #898
# Calling for doc #899
# Calling for doc #900
# Calling for doc #901
# Calling for doc #902
# Calling for doc #903
# Calling for doc #904
# Calling for doc #905
# Calling for doc #906
# Calling for doc #907
# Calling for doc #908
# Calling for doc #909
# Calling for doc #910
# Calling for doc #911
# Calling for doc #912
# Calling for doc #913
# Calling for doc #914
# Calling for doc #915
# Calling for doc #916
# Calling for doc #917
# Calling for doc #918
# Calling for doc #919
# Calling for doc #920
# Calling for doc #921
# Calling for doc #922
# Calling for doc #923
# Calling for doc #924
# Calling for doc #925
# Calling for doc #926
# Calling for doc #927
# Calling for doc #928
# Calling for doc #929
# Calling for doc #930
# Calling for doc #931
# Calling for doc #932
# Calling for doc #933
# Calling for doc #934
# Calling for doc #935
# Calling for doc #936
# Calling for doc #937
# Calling for doc #938
# Calling for doc #939
# Calling for doc #940
# Calling for doc #941
# Calling for doc #942
# Calling for doc #943
# Calling for doc #944
# Calling for doc #945
# Calling for doc #946
# Calling for doc #947
# Calling for doc #948
# Calling for doc #949
# Calling for doc #950
# Calling for doc #951
# Calling for doc #952
# Calling for doc #953
# Calling for doc #954
# Calling for doc #955
# Calling for doc #956
# Calling for doc #957
# Calling for doc #958
# Calling for doc #959
# Calling for doc #960
# Calling for doc #961
# Calling for doc #962
# Calling for doc #963
# Calling for doc #964
# Calling for doc #965
# Calling for doc #966
# Calling for doc #967
# Calling for doc #968
# Calling for doc #969
# Calling for doc #970
# Calling for doc #971
# Calling for doc #972
# Calling for doc #973
# Calling for doc #974
# Calling for doc #975
# Calling for doc #976
# Calling for doc #977
# Calling for doc #978
# Calling for doc #979
# Calling for doc #980
# Calling for doc #981
# Calling for doc #982
# Calling for doc #983
# Calling for doc #984
# Calling for doc #985
# Calling for doc #986
# Calling for doc #987
# Calling for doc #988
# Calling for doc #989
# Calling for doc #990
# Calling for doc #991
# Calling for doc #992
# Calling for doc #993
# Calling for doc #994
# Calling for doc #995
# Calling for doc #996
# Calling for doc #997
# Calling for doc #998
# Calling for doc #999
# Calling for doc #1000
# Calling for doc #1001
# Calling for doc #1002
# Calling for doc #1003
# Calling for doc #1004
# Calling for doc #1005
# Calling for doc #1006
# Calling for doc #1007
# Calling for doc #1008
# Calling for doc #1009
# Calling for doc #1010
# Calling for doc #1011
# Calling for doc #1012
# Calling for doc #1013
# Calling for doc #1014
# Calling for doc #1015
# Calling for doc #1016
# Calling for doc #1017
# Calling for doc #1018
# Calling for doc #1019
# Calling for doc #1020
# Calling for doc #1021
# Calling for doc #1022
# Calling for doc #1023
# Calling for doc #1024
# Calling for doc #1025
# Calling for doc #1026
# Calling for doc #1027
# Calling for doc #1028
# Calling for doc #1029
# Calling for doc #1030
# Calling for doc #1031
# Calling for doc #1032
# Calling for doc #1033
# Calling for doc #1034
# Calling for doc #1035
# Calling for doc #1036
# Calling for doc #1037
# Calling for doc #1038
# Calling for doc #1039
# Calling for doc #1040
# Calling for doc #1041
# Calling for doc #1042
# Calling for doc #1043
# Calling for doc #1044
# Calling for doc #1045
# Calling for doc #1046
# Calling for doc #1047
# Calling for doc #1048
# Calling for doc #1049
# Calling for doc #1050
# Calling for doc #1051
# Calling for doc #1052
# Calling for doc #1053
# Calling for doc #1054
# Calling for doc #1055
# Calling for doc #1056
# Calling for doc #1057
# Calling for doc #1058
# Calling for doc #1059
# Calling for doc #1060
# Calling for doc #1061
# Calling for doc #1062
# Calling for doc #1063
# Calling for doc #1064
# Calling for doc #1065
# Calling for doc #1066
# Calling for doc #1067
# Calling for doc #1068
# Calling for doc #1069
# Calling for doc #1070
# Calling for doc #1071
# Calling for doc #1072
# Calling for doc #1073
# Calling for doc #1074
# Calling for doc #1075
# Calling for doc #1076
# Calling for doc #1077
# Calling for doc #1078
# Calling for doc #1079
# Calling for doc #1080
# Calling for doc #1081
# Calling for doc #1082
# Calling for doc #1083
# Calling for doc #1084
# Calling for doc #1085
# Calling for doc #1086
# Calling for doc #1087
# Calling for doc #1088
# Calling for doc #1089
# Calling for doc #1090
# Calling for doc #1091
# Calling for doc #1092
# Calling for doc #1093
# Calling for doc #1094
# Calling for doc #1095
# Calling for doc #1096
# Calling for doc #1097
# Calling for doc #1098
# Calling for doc #1099
# Calling for doc #1100
# Calling for doc #1101
# Calling for doc #1102
# Calling for doc #1103
# Calling for doc #1104
# Calling for doc #1105
# Calling for doc #1106
# Calling for doc #1107
# Calling for doc #1108
# Calling for doc #1109
# Calling for doc #1110
# Calling for doc #1111
# Calling for doc #1112
# Calling for doc #1113
# Calling for doc #1114
# Calling for doc #1115
# Calling for doc #1116
# Calling for doc #1117
# Calling for doc #1118
# Calling for doc #1119
# Calling for doc #1120
# Calling for doc #1121
# Calling for doc #1122
# Calling for doc #1123
# Calling for doc #1124
# Calling for doc #1125
# Calling for doc #1126
# Calling for doc #1127
# Calling for doc #1128
# Calling for doc #1129
# Calling for doc #1130
# Calling for doc #1131
# Calling for doc #1132
# Calling for doc #1133
# Calling for doc #1134
# Calling for doc #1135
# Calling for doc #1136
# Calling for doc #1137
# Calling for doc #1138
# Calling for doc #1139
# Calling for doc #1140
# Calling for doc #1141
# Calling for doc #1142
# Calling for doc #1143
# Calling for doc #1144
# Calling for doc #1145
# Calling for doc #1146
# Calling for doc #1147
# Calling for doc #1148
# Calling for doc #1149
# Calling for doc #1150
# Calling for doc #1151
# Calling for doc #1152
# Calling for doc #1153
# Calling for doc #1154
# Calling for doc #1155
# Calling for doc #1156
# Calling for doc #1157
# Calling for doc #1158
# Calling for doc #1159
# Calling for doc #1160
# Calling for doc #1161
# Calling for doc #1162
# Calling for doc #1163
# Calling for doc #1164
# Calling for doc #1165
# Calling for doc #1166
# Calling for doc #1167
# Calling for doc #1168
# Calling for doc #1169
# Calling for doc #1170
# Calling for doc #1171
# Calling for doc #1172
# Calling for doc #1173
# Calling for doc #1174
# Calling for doc #1175
# Calling for doc #1176
# Calling for doc #1177
# Calling for doc #1178
# Calling for doc #1179
# Calling for doc #1180
# Calling for doc #1181
# Calling for doc #1182
# Calling for doc #1183
# Calling for doc #1184
# Calling for doc #1185
# Calling for doc #1186
# Calling for doc #1187
# Calling for doc #1188
# Calling for doc #1189
# Calling for doc #1190
# Calling for doc #1191
# Calling for doc #1192
# Calling for doc #1193
# Calling for doc #1194
# Calling for doc #1195
# Calling for doc #1196
# Calling for doc #1197
# Calling for doc #1198
# Calling for doc #1199
# Calling for doc #1200
# Calling for doc #1201
# Calling for doc #1202
# Calling for doc #1203
# Calling for doc #1204
# Calling for doc #1205
# Calling for doc #1206
# Calling for doc #1207
# Calling for doc #1208
# Calling for doc #1209
# Calling for doc #1210
# Calling for doc #1211
# Calling for doc #1212
# Calling for doc #1213
# Calling for doc #1214
# Calling for doc #1215
# Calling for doc #1216
# Calling for doc #1217
# Calling for doc #1218
# Calling for doc #1219
# Calling for doc #1220
# Calling for doc #1221
# Calling for doc #1222
# Calling for doc #1223
# Calling for doc #1224
# Calling for doc #1225
# Calling for doc #1226
# Calling for doc #1227
# Calling for doc #1228
# Calling for doc #1229
# Calling for doc #1230
# Calling for doc #1231
# Calling for doc #1232
# Calling for doc #1233
# Calling for doc #1234
# Calling for doc #1235
# Calling for doc #1236
# Calling for doc #1237
# Calling for doc #1238
# Calling for doc #1239
# Calling for doc #1240
# Calling for doc #1241
# Calling for doc #1242
# Calling for doc #1243
# Calling for doc #1244
# Calling for doc #1245
# Calling for doc #1246
# Calling for doc #1247
# Calling for doc #1248
# Calling for doc #1249
# Calling for doc #1250
# Calling for doc #1251
# Calling for doc #1252
# Calling for doc #1253
# Calling for doc #1254
# Calling for doc #1255
# Calling for doc #1256
# Calling for doc #1257
# Calling for doc #1258
# Calling for doc #1259
# Calling for doc #1260
# Calling for doc #1261
# Calling for doc #1262
# Calling for doc #1263
# Calling for doc #1264
# Calling for doc #1265
# Calling for doc #1266
# Calling for doc #1267
# Calling for doc #1268
# Calling for doc #1269
# Calling for doc #1270
# Calling for doc #1271
# Calling for doc #1272
# Calling for doc #1273
# Calling for doc #1274
# Calling for doc #1275
# Calling for doc #1276
# Calling for doc #1277
# Calling for doc #1278
# Calling for doc #1279
# Calling for doc #1280
# Calling for doc #1281
# Calling for doc #1282
# Calling for doc #1283
# Calling for doc #1284
# Calling for doc #1285
# Calling for doc #1286
# Calling for doc #1287
# Calling for doc #1288
# Calling for doc #1289
# Calling for doc #1290
# Calling for doc #1291
# Calling for doc #1292
# Calling for doc #1293
# Calling for doc #1294
# Calling for doc #1295
# Calling for doc #1296
# Calling for doc #1297
# Calling for doc #1298
# Calling for doc #1299
# Calling for doc #1300
# Calling for doc #1301
# Calling for doc #1302
# Calling for doc #1303
# Calling for doc #1304
# Calling for doc #1305
# Calling for doc #1306
# Calling for doc #1307
# Calling for doc #1308
# Calling for doc #1309
# Calling for doc #1310
# Calling for doc #1311
# Calling for doc #1312
# Calling for doc #1313
# Calling for doc #1314
# Calling for doc #1315
# Calling for doc #1316
# Calling for doc #1317
# Calling for doc #1318
# Calling for doc #1319
# Calling for doc #1320
# Calling for doc #1321
# Calling for doc #1322
# Calling for doc #1323
# Calling for doc #1324
# Calling for doc #1325
# Calling for doc #1326
# Calling for doc #1327
# Calling for doc #1328
# Calling for doc #1329
# Calling for doc #1330
# Calling for doc #1331
# Calling for doc #1332
# Calling for doc #1333
# Calling for doc #1334
# Calling for doc #1335
# Calling for doc #1336
# Calling for doc #1337
# Calling for doc #1338
# Calling for doc #1339
# Calling for doc #1340
# Calling for doc #1341
# Calling for doc #1342
# Calling for doc #1343
# Calling for doc #1344
# Calling for doc #1345
# Calling for doc #1346
# Calling for doc #1347
# Calling for doc #1348
# Calling for doc #1349
# Calling for doc #1350
# Calling for doc #1351
# Calling for doc #1352
# Calling for doc #1353
# Calling for doc #1354
# Calling for doc #1355
# Calling for doc #1356
# Calling for doc #1357
# Calling for doc #1358
# Calling for doc #1359
# Calling for doc #1360
# Calling for doc #1361
# Calling for doc #1362
# Calling for doc #1363
# Calling for doc #1364
# Calling for doc #1365
# Calling for doc #1366
# Calling for doc #1367
# Calling for doc #1368
# Calling for doc #1369
# Calling for doc #1370
# Calling for doc #1371
# Calling for doc #1372
# Calling for doc #1373
# Calling for doc #1374
# Calling for doc #1375
# Calling for doc #1376
# Calling for doc #1377
# Calling for doc #1378
# Calling for doc #1379
# Calling for doc #1380
# Calling for doc #1381
# Calling for doc #1382
# Calling for doc #1383
# Calling for doc #1384
# Calling for doc #1385
# Calling for doc #1386
# Calling for doc #1387
# Calling for doc #1388
# Calling for doc #1389
# Calling for doc #1390
# Calling for doc #1391
# Calling for doc #1392
# Calling for doc #1393
# Calling for doc #1394
# Calling for doc #1395
# Calling for doc #1396
# Calling for doc #1397
# Calling for doc #1398
# Calling for doc #1399
# Calling for doc #1400
# Calling for doc #1401
# Calling for doc #1402
# Calling for doc #1403
# Calling for doc #1404
# Calling for doc #1405
# Calling for doc #1406
# Calling for doc #1407
# Calling for doc #1408
# Calling for doc #1409
# Calling for doc #1410
# Calling for doc #1411
# Calling for doc #1412
# Calling for doc #1413
# Calling for doc #1414
# Calling for doc #1415
# Calling for doc #1416
# Calling for doc #1417
# Calling for doc #1418
# Calling for doc #1419
# Calling for doc #1420
# Calling for doc #1421
# Calling for doc #1422
# Calling for doc #1423
# Calling for doc #1424
# Calling for doc #1425
# Calling for doc #1426
# Calling for doc #1427
# Calling for doc #1428
# Calling for doc #1429
# Calling for doc #1430
# Calling for doc #1431
# Calling for doc #1432
# Calling for doc #1433
# Calling for doc #1434
# Calling for doc #1435
# Calling for doc #1436
# Calling for doc #1437
# Calling for doc #1438
# Calling for doc #1439
# Calling for doc #1440
# Calling for doc #1441
# Calling for doc #1442
# Calling for doc #1443
# Calling for doc #1444
# Calling for doc #1445
# Calling for doc #1446
# Calling for doc #1447
# Calling for doc #1448
# Calling for doc #1449
# Calling for doc #1450
# Calling for doc #1451
# Calling for doc #1452
# Calling for doc #1453
# Calling for doc #1454
# Calling for doc #1455
# Calling for doc #1456
# Calling for doc #1457
# Calling for doc #1458
# Calling for doc #1459
# Calling for doc #1460
# Calling for doc #1461
# Calling for doc #1462
# Calling for doc #1463
# Calling for doc #1464
# Calling for doc #1465
# Calling for doc #1466
# Calling for doc #1467
# Calling for doc #1468
# Calling for doc #1469
# Calling for doc #1470
# Calling for doc #1471
# Calling for doc #1472
# Calling for doc #1473
# Calling for doc #1474
# Calling for doc #1475
# Calling for doc #1476
# Calling for doc #1477
# Calling for doc #1478
# Calling for doc #1479
# Calling for doc #1480
# Calling for doc #1481
# Calling for doc #1482
# Calling for doc #1483
# Calling for doc #1484
# Calling for doc #1485
# Calling for doc #1486
# Calling for doc #1487
# Calling for doc #1488
# Calling for doc #1489
# Calling for doc #1490
# Calling for doc #1491
# Calling for doc #1492
# Calling for doc #1493
# Calling for doc #1494
# Calling for doc #1495
# Calling for doc #1496
# Calling for doc #1497
# Calling for doc #1498
# Calling for doc #1499
# Calling for doc #1500
# Calling for doc #1501
# Calling for doc #1502
# Calling for doc #1503
# Calling for doc #1504
# Calling for doc #1505
# Calling for doc #1506
# Calling for doc #1507
# Calling for doc #1508
# Calling for doc #1509
# Calling for doc #1510
# Calling for doc #1511
# Calling for doc #1512
# Token limit for doc #1482 exceeded, reducing the prompt size.
# Calling for doc #1482
# Calling for doc #1513
# Calling for doc #1514
# Calling for doc #1515
# Calling for doc #1516
# Calling for doc #1517
# Calling for doc #1518
# Calling for doc #1519
# Calling for doc #1520
# Calling for doc #1521
# Calling for doc #1522
# Calling for doc #1523
# Calling for doc #1524
# Calling for doc #1525
# Calling for doc #1526
# Calling for doc #1527
# Calling for doc #1528
# Calling for doc #1529
# Calling for doc #1530
# Calling for doc #1531
# Calling for doc #1532
# Calling for doc #1533
# Calling for doc #1534
# Calling for doc #1535
# Calling for doc #1536
# Calling for doc #1537
# Calling for doc #1538
# Calling for doc #1539
# Calling for doc #1540
# Calling for doc #1541
# Calling for doc #1542
# Calling for doc #1543
# Calling for doc #1544
# Calling for doc #1545
# Calling for doc #1546
# Calling for doc #1547
# Calling for doc #1548
# Calling for doc #1549
# Calling for doc #1550
# Calling for doc #1551
# Calling for doc #1552
# Calling for doc #1553
# Calling for doc #1554
# Calling for doc #1555
# Calling for doc #1556
# Calling for doc #1557
# Calling for doc #1558
# Calling for doc #1559
# Calling for doc #1560
# Calling for doc #1561
# Calling for doc #1562
# Calling for doc #1563
# Calling for doc #1564
# Calling for doc #1565
# Calling for doc #1566
# Calling for doc #1567
# Calling for doc #1568
# Calling for doc #1569
# Calling for doc #1570
# Calling for doc #1571
# Calling for doc #1572
# Calling for doc #1573
# Calling for doc #1574
# Calling for doc #1575
# Calling for doc #1576
# Calling for doc #1577
# Calling for doc #1578
# Calling for doc #1579
# Calling for doc #1580
# Calling for doc #1581
# Calling for doc #1582
# Calling for doc #1583
# Calling for doc #1584
# Calling for doc #1585
# Calling for doc #1586
# Calling for doc #1587
# Calling for doc #1588
# Calling for doc #1589
# Calling for doc #1590
# Calling for doc #1591
# Calling for doc #1592
# Calling for doc #1593
# Calling for doc #1594
# Calling for doc #1595
# Calling for doc #1596
# Calling for doc #1597
# Calling for doc #1598
# Calling for doc #1599
# Calling for doc #1600
# Calling for doc #1601
# Calling for doc #1602
# Calling for doc #1603
# Calling for doc #1604
# Calling for doc #1605
# Calling for doc #1606
# Calling for doc #1607
# Calling for doc #1608
# Calling for doc #1609
# Calling for doc #1610
# Calling for doc #1611
# Calling for doc #1612
# Calling for doc #1613
# Calling for doc #1614
# Calling for doc #1615
# Calling for doc #1616
# Calling for doc #1617
# Calling for doc #1618
# Calling for doc #1619
# Calling for doc #1620
# Calling for doc #1621
# Calling for doc #1622
# Calling for doc #1623
# Calling for doc #1624
# Calling for doc #1625
# Calling for doc #1626
# Calling for doc #1627
# Calling for doc #1628
# Calling for doc #1629
# Calling for doc #1630
# Calling for doc #1631
# Calling for doc #1632
# Calling for doc #1633
# Calling for doc #1634
# Calling for doc #1635
# Calling for doc #1636
# Calling for doc #1637
# Calling for doc #1638
# Calling for doc #1639
# Calling for doc #1640
# Calling for doc #1641
# Calling for doc #1642
# Calling for doc #1643
# Calling for doc #1644
# Calling for doc #1645
# Calling for doc #1646
# Calling for doc #1647
# Calling for doc #1648
# Calling for doc #1649
# Calling for doc #1650
# Calling for doc #1651
# Calling for doc #1652
# Calling for doc #1653
# Calling for doc #1654
# Calling for doc #1655
# Calling for doc #1656
# Calling for doc #1657
# Calling for doc #1658
# Calling for doc #1659
# Calling for doc #1660
# Calling for doc #1661
# Calling for doc #1662
# Calling for doc #1663
# Calling for doc #1664
# Calling for doc #1665
# Calling for doc #1666
# Calling for doc #1667
# Calling for doc #1668
# Calling for doc #1669
# Calling for doc #1670
# Calling for doc #1671
# Calling for doc #1672
# Calling for doc #1673
# Calling for doc #1674
# Calling for doc #1675
# Calling for doc #1676
# Calling for doc #1677
# Calling for doc #1678
# Calling for doc #1679
# Calling for doc #1680
# Calling for doc #1681
# Calling for doc #1682
# Calling for doc #1683
# Calling for doc #1684
# Calling for doc #1685
# Calling for doc #1686
# Calling for doc #1687
# Calling for doc #1688
# Calling for doc #1689
# Calling for doc #1690
# Calling for doc #1691
# Calling for doc #1692
# Calling for doc #1693
# Calling for doc #1694
# Calling for doc #1695
# Calling for doc #1696
# Calling for doc #1697
# Calling for doc #1698
# Calling for doc #1699
# Calling for doc #1700
# Calling for doc #1701
# Calling for doc #1702
# Calling for doc #1703
# Calling for doc #1704
# Calling for doc #1705
# Calling for doc #1706
# Calling for doc #1707
# Calling for doc #1708
# Calling for doc #1709
# Calling for doc #1710
# Calling for doc #1711
# Calling for doc #1712
# Calling for doc #1713
# Calling for doc #1714
# Calling for doc #1715
# Calling for doc #1716
# Calling for doc #1717
# Calling for doc #1718
# Calling for doc #1719
# Calling for doc #1720
# Calling for doc #1721
# Calling for doc #1722
# Calling for doc #1723
# Calling for doc #1724
# Calling for doc #1725
# Calling for doc #1726
# Calling for doc #1727
# Calling for doc #1728
# Calling for doc #1729
# Calling for doc #1730
# Calling for doc #1731
# Calling for doc #1732
# Calling for doc #1733
# Calling for doc #1734
# Calling for doc #1735
# Calling for doc #1736
# Calling for doc #1737
# Calling for doc #1738
# Calling for doc #1739
# Calling for doc #1740
# Calling for doc #1741
# Calling for doc #1742
# Calling for doc #1743
# Calling for doc #1744
# Calling for doc #1745
# Calling for doc #1746
# Calling for doc #1747
# Calling for doc #1748
# Calling for doc #1749
# Calling for doc #1750
# Calling for doc #1751
# Calling for doc #1752
# Calling for doc #1753
# Calling for doc #1754
# Calling for doc #1755
# Calling for doc #1756
# Calling for doc #1757
# Calling for doc #1758
# Calling for doc #1759
# Calling for doc #1760
# Calling for doc #1761
# Calling for doc #1762
# Calling for doc #1763
# Calling for doc #1764
# Calling for doc #1765
# Calling for doc #1766
# Calling for doc #1767
# Calling for doc #1768
# Calling for doc #1769
# Calling for doc #1770
# Calling for doc #1771
# Calling for doc #1772
# Calling for doc #1773
# Calling for doc #1774
# Calling for doc #1775
# Calling for doc #1776
# Calling for doc #1777
# Calling for doc #1778
# Calling for doc #1779
# Calling for doc #1780
# Calling for doc #1781
# Calling for doc #1782
# Calling for doc #1783
# Calling for doc #1784
# Calling for doc #1785
# Calling for doc #1786
# Calling for doc #1787
# Calling for doc #1788
# Calling for doc #1789
# Calling for doc #1790
# Calling for doc #1791
# Calling for doc #1792
# Calling for doc #1793
# Calling for doc #1794
# Calling for doc #1795
# Calling for doc #1796
# Calling for doc #1797
# Calling for doc #1798
# Calling for doc #1799
# Calling for doc #1800
# Calling for doc #1801
# Calling for doc #1802
# Calling for doc #1803
# Calling for doc #1804
# Calling for doc #1805
# Calling for doc #1806
# Calling for doc #1807
# Calling for doc #1808
# Calling for doc #1809
# Calling for doc #1810
# Calling for doc #1811
# Calling for doc #1812
# Calling for doc #1813
# Calling for doc #1814
# Calling for doc #1815
# Calling for doc #1816
# Calling for doc #1817
# Calling for doc #1818
# Calling for doc #1819
# Calling for doc #1820
# Calling for doc #1821
# Calling for doc #1822
# Calling for doc #1823
# Calling for doc #1824
# Calling for doc #1825
# Calling for doc #1826
# Calling for doc #1827
# Calling for doc #1828
# Calling for doc #1829
# Calling for doc #1830
# Calling for doc #1831
# Calling for doc #1832
# Calling for doc #1833
# Calling for doc #1834
# Calling for doc #1835
# Calling for doc #1836
# Calling for doc #1837
# Calling for doc #1838
# Calling for doc #1839
# Calling for doc #1840
# Calling for doc #1841
# Calling for doc #1842
# Calling for doc #1843
# Calling for doc #1844
# Calling for doc #1845
# Calling for doc #1846
# Calling for doc #1847
# Calling for doc #1848
# Calling for doc #1849
# Calling for doc #1850
# Calling for doc #1851
# Calling for doc #1852
# Calling for doc #1853
# Calling for doc #1854
# Calling for doc #1855
# Calling for doc #1856
# Calling for doc #1857
# Calling for doc #1858
# Calling for doc #1859
# Calling for doc #1860
# Calling for doc #1861
# Calling for doc #1862
# Calling for doc #1863
# Calling for doc #1864
# Calling for doc #1865
# Calling for doc #1866
# Calling for doc #1867
# Calling for doc #1868
# Calling for doc #1869
# Calling for doc #1870
# Calling for doc #1871
# Calling for doc #1872
# Calling for doc #1873
# Calling for doc #1874
# Calling for doc #1875
# Calling for doc #1876
# Calling for doc #1877
# Calling for doc #1878
# Calling for doc #1879
# Calling for doc #1880
# Calling for doc #1881
# Calling for doc #1882
# Calling for doc #1883
# Calling for doc #1884
# Calling for doc #1885
# Calling for doc #1886
# Calling for doc #1887
# Calling for doc #1888
# Calling for doc #1889
# Calling for doc #1890
# Calling for doc #1891
# Calling for doc #1892
# Calling for doc #1893
# Calling for doc #1894
# Calling for doc #1895
# Calling for doc #1896
# Calling for doc #1897
# Calling for doc #1898
# Calling for doc #1899
# Calling for doc #1900
# Calling for doc #1901
# Calling for doc #1902
# Calling for doc #1903
# Calling for doc #1904
# Calling for doc #1905
# Calling for doc #1906
# Calling for doc #1907
# Calling for doc #1908
# Calling for doc #1909
# Calling for doc #1910
# Calling for doc #1911
# Calling for doc #1912
# Calling for doc #1913
# Calling for doc #1914
# Calling for doc #1915
# Calling for doc #1916
# Calling for doc #1917
# Calling for doc #1918
# Calling for doc #1919
# Calling for doc #1920
# Calling for doc #1921
# Calling for doc #1922
# Calling for doc #1923
# Calling for doc #1924
# Calling for doc #1925
# Calling for doc #1926
# Calling for doc #1927
# Calling for doc #1928
# Calling for doc #1929
# Calling for doc #1930
# Calling for doc #1931
# Calling for doc #1932
# Calling for doc #1933
# Calling for doc #1934
# Calling for doc #1935
# Calling for doc #1936
# Calling for doc #1937
# Calling for doc #1938
# Calling for doc #1939
# Calling for doc #1940
# Calling for doc #1941
# Calling for doc #1942
# Calling for doc #1943
# Calling for doc #1944
# Calling for doc #1945
# Calling for doc #1946
# Calling for doc #1947
# Calling for doc #1948
# Calling for doc #1949
# Calling for doc #1950
# Calling for doc #1951
# Calling for doc #1952
# Calling for doc #1953
# Calling for doc #1954
# Calling for doc #1955
# Calling for doc #1956
# Calling for doc #1957
# Calling for doc #1958
# Calling for doc #1959
# Calling for doc #1960
# Calling for doc #1961
# Calling for doc #1962
# Calling for doc #1963
# Calling for doc #1964
# Calling for doc #1965
# Calling for doc #1966
# Calling for doc #1967
# Calling for doc #1968
# Calling for doc #1969
# Calling for doc #1970
# Calling for doc #1971
# Calling for doc #1972
# Calling for doc #1973
# Calling for doc #1974
# Calling for doc #1975
# Calling for doc #1976
# Calling for doc #1977
# Calling for doc #1978
# Calling for doc #1979
# Calling for doc #1980
# Calling for doc #1981
# Calling for doc #1982
# Calling for doc #1983
# Calling for doc #1984
# Calling for doc #1985
# Calling for doc #1986
# Calling for doc #1987
# Calling for doc #1988
# Calling for doc #1989
# Calling for doc #1990
# Calling for doc #1991
# Calling for doc #1992
# Calling for doc #1993
# Calling for doc #1994
# Calling for doc #1995
# Calling for doc #1996
# Calling for doc #1997
# Calling for doc #1998
# Calling for doc #1999
# Calling for doc #2000
# Calling for doc #2001
# Calling for doc #2002
# Calling for doc #2003
# Calling for doc #2004
# Calling for doc #2005
# Calling for doc #2006
# Calling for doc #2007
# Calling for doc #2008
# Calling for doc #2009
# Calling for doc #2010
# Calling for doc #2011
# Calling for doc #2012
# Calling for doc #2013
# Calling for doc #2014
# Calling for doc #2015
# Calling for doc #2016
# Calling for doc #2017
# Calling for doc #2018
# Calling for doc #2019
# Calling for doc #2020
# Token limit for doc #1991 exceeded, reducing the prompt size.
# Calling for doc #1991
# Calling for doc #2021
# Calling for doc #2022
# Calling for doc #2023
# Calling for doc #2024
# Calling for doc #2025
# Calling for doc #2026
# Calling for doc #2027
# Calling for doc #2028
# Calling for doc #2029
# Calling for doc #2030
# Calling for doc #2031
# Calling for doc #2032
# Calling for doc #2033
# Calling for doc #2034
# Calling for doc #2035
# Calling for doc #2036
# Calling for doc #2037
# Calling for doc #2038
# Calling for doc #2039
# Calling for doc #2040
# Calling for doc #2041
# Calling for doc #2042
# Calling for doc #2043
# Calling for doc #2044
# Calling for doc #2045
# Calling for doc #2046
# Calling for doc #2047
# Calling for doc #2048
# Calling for doc #2049
# Calling for doc #2050
# Calling for doc #2051
# Calling for doc #2052
# Calling for doc #2053
# Calling for doc #2054
# Calling for doc #2055
# Calling for doc #2056
# Calling for doc #2057
# Calling for doc #2058
# Calling for doc #2059
# Calling for doc #2060
# Calling for doc #2061
# Calling for doc #2062
# Calling for doc #2063
# Calling for doc #2064
# Calling for doc #2065
# Calling for doc #2066
# Calling for doc #2067
# Calling for doc #2068
# Calling for doc #2069
# Token limit for doc #1991 exceeded, reducing the prompt size.
# Calling for doc #1991
# Calling for doc #2070
# Calling for doc #2071
# Calling for doc #2072
# Calling for doc #2073
# Calling for doc #2074
# Calling for doc #2075
# Calling for doc #2076
# Calling for doc #2077
# Calling for doc #2078
# Calling for doc #2079
# Calling for doc #2080
# Calling for doc #2081
# Calling for doc #2082
# Calling for doc #2083
# Calling for doc #2084
# Calling for doc #2085
# Calling for doc #2086
# Calling for doc #2087
# Calling for doc #2088
# Calling for doc #2089
# Calling for doc #2090
# Calling for doc #2091
# Calling for doc #2092
# Calling for doc #2093
# Calling for doc #2094
# Calling for doc #2095
# Calling for doc #2096
# Calling for doc #2097
# Calling for doc #2098
# Calling for doc #2099
# Calling for doc #2100
# Calling for doc #2101
# Calling for doc #2102
# Calling for doc #2103
# Calling for doc #2104
# Calling for doc #2105
# Calling for doc #2106
# Calling for doc #2107
# Calling for doc #2108
# Calling for doc #2109
# Calling for doc #2110
# Calling for doc #2111
# Calling for doc #2112
# Calling for doc #2113
# Calling for doc #2114
# Calling for doc #2115
# Token limit for doc #1991 exceeded, reducing the prompt size.
# Calling for doc #1991
# Calling for doc #2116
# Calling for doc #2117
# Calling for doc #2118
# Calling for doc #2119
# Calling for doc #2120
# Calling for doc #2121
# Calling for doc #2122
# Calling for doc #2123
# Calling for doc #2124
# Calling for doc #2125
# Calling for doc #2126
# Calling for doc #2127
# Calling for doc #2128
# Calling for doc #2129
# Calling for doc #2130
# Calling for doc #2131
# Calling for doc #2132
# Calling for doc #2133
# Calling for doc #2134
# Calling for doc #2135
# Calling for doc #2136
# Calling for doc #2137
# Calling for doc #2138
# Calling for doc #2139
# Calling for doc #2140
# Calling for doc #2141
# Calling for doc #2142
# Calling for doc #2143
# Calling for doc #2144
# Calling for doc #2145
# Calling for doc #2146
# Calling for doc #2147
# Calling for doc #2148
# Calling for doc #2149
# Calling for doc #2150
# Calling for doc #2151
# Calling for doc #2152
# Calling for doc #2153
# Calling for doc #2154
# Calling for doc #2155
# Calling for doc #2156
# Calling for doc #2157
# Calling for doc #2158
# Calling for doc #2159
# Calling for doc #2160
# Calling for doc #2161
# Calling for doc #2162
# Calling for doc #2163
# Calling for doc #2164
# Calling for doc #2165
# Calling for doc #2166
# Calling for doc #2167
# Calling for doc #2168
# Calling for doc #2169
# Calling for doc #2170
# Calling for doc #2171
# Calling for doc #2172
# Calling for doc #2173
# Calling for doc #2174
# Calling for doc #2175
# Calling for doc #2176
# Calling for doc #2177
# Calling for doc #2178
# Calling for doc #2179
# Calling for doc #2180
# Calling for doc #2181
# Calling for doc #2182
# Calling for doc #2183
# Calling for doc #2184
# Calling for doc #2185
# Calling for doc #2186
# Calling for doc #2187
# Calling for doc #2188
# Calling for doc #2189
# Calling for doc #2190
# Calling for doc #2191
# Calling for doc #2192
# Calling for doc #2193
# Calling for doc #2194
# Calling for doc #2195
# Calling for doc #2196
# Calling for doc #2197
# Calling for doc #2198
# Calling for doc #2199
# Calling for doc #2200
# Calling for doc #2201
# Calling for doc #2202
# Calling for doc #2203
# Calling for doc #2204
# Calling for doc #2205
# Calling for doc #2206
# Calling for doc #2207
# Calling for doc #2208
# Calling for doc #2209
# Calling for doc #2210
# Calling for doc #2211
# Calling for doc #2212
# Calling for doc #2213
# Calling for doc #2214
# Calling for doc #2215
# Calling for doc #2216
# ...
# Calling for doc #31905
# Token limit for doc #31873 exceeded, reducing the prompt size.
# Calling for doc #31873
# Token limit for doc #31857 exceeded, reducing the prompt size.
# Calling for doc #31857
# Calling for doc #31906
# Calling for doc #31907
# Calling for doc #31908
# Calling for doc #31909
# Calling for doc #31910
# Calling for doc #31911
# Calling for doc #31912
# Calling for doc #31913
# Calling for doc #31914
# Calling for doc #31915
# Calling for doc #31916
# Calling for doc #31917
# Calling for doc #31918
# Calling for doc #31919
# Calling for doc #31920
# Calling for doc #31921
# Calling for doc #31922
# Calling for doc #31923
# Calling for doc #31924
# Calling for doc #31925
# Calling for doc #31926
# Calling for doc #31927
# Calling for doc #31928
# Calling for doc #31929
# Calling for doc #31930
# Calling for doc #31931
# Calling for doc #31932
# Calling for doc #31933
# Calling for doc #31934
# Calling for doc #31935
# Calling for doc #31936
# Calling for doc #31937
# Calling for doc #31938
# Calling for doc #31939
# Calling for doc #31940
# Calling for doc #31941
# Calling for doc #31942
# Calling for doc #31943
# Calling for doc #31944
# Calling for doc #31945
# Calling for doc #31946
# Calling for doc #31947
# Calling for doc #31948
# Calling for doc #31949
# Calling for doc #31950
# Calling for doc #31951
# Calling for doc #31952
# Calling for doc #31953
# Token limit for doc #31873 exceeded, reducing the prompt size.
# Calling for doc #31873
# Token limit for doc #31857 exceeded, reducing the prompt size.
# Calling for doc #31857
# Calling for doc #31954
# Calling for doc #31955
# Calling for doc #31956
# Calling for doc #31957
# Calling for doc #31958
# Calling for doc #31959
# Calling for doc #31960
# Calling for doc #31961
# Calling for doc #31962
# Calling for doc #31963
# Calling for doc #31964
# Calling for doc #31965
# Calling for doc #31966
# Calling for doc #31967
# Calling for doc #31968
# Calling for doc #31969
# Calling for doc #31970
# Calling for doc #31971
# Calling for doc #31972
# Calling for doc #31973
# Calling for doc #31974
# Calling for doc #31975
# Calling for doc #31976
# Calling for doc #31977
# Calling for doc #31978
# Calling for doc #31979
# Calling for doc #31980
# Calling for doc #31981
# Calling for doc #31982
# Calling for doc #31983
# Calling for doc #31984
# Calling for doc #31985
# Calling for doc #31986
# Calling for doc #31987
# Calling for doc #31988
# Calling for doc #31989
# Calling for doc #31990
# Calling for doc #31991
# Calling for doc #31992
# Calling for doc #31993
# Calling for doc #31994
# Calling for doc #31995
# Calling for doc #31996
# Calling for doc #31997
# Calling for doc #31998
# Calling for doc #31999
# Calling for doc #32000
# Calling for doc #32001
# Token limit for doc #31873 exceeded, reducing the prompt size.
# Calling for doc #31873
# Token limit for doc #31857 exceeded, reducing the prompt size.
# Calling for doc #31857
# Calling for doc #32002
# Calling for doc #32003
# Calling for doc #32004
# Calling for doc #32005
# Calling for doc #32006
# Calling for doc #32007
# Calling for doc #32008
# Calling for doc #32009
# Calling for doc #32010
# Calling for doc #32011
# Calling for doc #32012
# Calling for doc #32013
# Calling for doc #32014
# Calling for doc #32015
# Calling for doc #32016
# Calling for doc #32017
# Calling for doc #32018
# Calling for doc #32019
# Calling for doc #32020
# Calling for doc #32021
# Calling for doc #32022
# Token limit for doc #31997 exceeded, reducing the prompt size.
# Calling for doc #31997
# Calling for doc #32023
# Calling for doc #32024
# Calling for doc #32025
# Calling for doc #32026
# Calling for doc #32027
# Calling for doc #32028
# Calling for doc #32029
# Calling for doc #32030
# Token limit for doc #31873 exceeded, reducing the prompt size.
# Calling for doc #31873
# Calling for doc #32031
# Calling for doc #32032
# Calling for doc #32033
# Calling for doc #32034
# Calling for doc #32035
# Calling for doc #32036
# Calling for doc #32037
# Calling for doc #32038
# Calling for doc #32039
# Calling for doc #32040
# Calling for doc #32041
# Calling for doc #32042
# Calling for doc #32043
# Calling for doc #32044
# Calling for doc #32045
# Calling for doc #32046
# Calling for doc #32047
# Calling for doc #32048
# Token limit for doc #31857 exceeded, reducing the prompt size.
# Calling for doc #31857
# Calling for doc #32049
# Calling for doc #32050
# Calling for doc #32051
# Calling for doc #32052
# Calling for doc #32053
# Calling for doc #32054
# Calling for doc #32055
# Calling for doc #32056
# Calling for doc #32057
# Calling for doc #32058
# Calling for doc #32059
# Calling for doc #32060
# Calling for doc #32061
# Calling for doc #32062
# Calling for doc #32063
# Calling for doc #32064
# Calling for doc #32065
# Calling for doc #32066
# Calling for doc #32067
# Calling for doc #32068
# Calling for doc #32069
# Token limit for doc #31873 exceeded, reducing the prompt size.
# Calling for doc #31873
# Calling for doc #32070
# Calling for doc #32071
# Calling for doc #32072
# Calling for doc #32073
# Calling for doc #32074
# Calling for doc #32075
# Token limit for doc #31857 exceeded, reducing the prompt size.
# Calling for doc #31857
# Calling for doc #32076
# Calling for doc #32077
# Calling for doc #32078
# Calling for doc #32079
# Calling for doc #32080
# Calling for doc #32081
# Calling for doc #32082
# Calling for doc #32083
# Calling for doc #32084
# Calling for doc #32085
# Calling for doc #32086
# Calling for doc #32087
# Calling for doc #32088
# Calling for doc #32089
# Calling for doc #32090
# Calling for doc #32091
# Calling for doc #32092
# Calling for doc #32093
# Calling for doc #32094
# Calling for doc #32095
# Calling for doc #32096
# Token limit for doc #31873 exceeded, reducing the prompt size.
# Calling for doc #31873
# Calling for doc #32097
# Calling for doc #32098
# Calling for doc #32099
# Token limit for doc #32071 exceeded, reducing the prompt size.
# Calling for doc #32071
# Calling for doc #32100
# Calling for doc #32101
# Calling for doc #32102
# Calling for doc #32103
# Calling for doc #32104
# Calling for doc #32105
# Calling for doc #32106
# Calling for doc #32107
# Calling for doc #32108
# Calling for doc #32109
# Calling for doc #32110
# Calling for doc #32111
# Calling for doc #32112
# Calling for doc #32113
# Calling for doc #32114
# Calling for doc #32115
# Calling for doc #32116
# Calling for doc #32117
# Calling for doc #32118
# Token limit for doc #31857 exceeded, reducing the prompt size.
# Calling for doc #31857
# Calling for doc #32119
# Calling for doc #32120
# Calling for doc #32121
# Calling for doc #32122
# Calling for doc #32123
# Calling for doc #32124
# Calling for doc #32125
# Calling for doc #32126
# Calling for doc #32127
# Calling for doc #32128
# Calling for doc #32129
# Calling for doc #32130
# Calling for doc #32131
# Calling for doc #32132
# Calling for doc #32133
# Calling for doc #32134
# Calling for doc #32135
# Calling for doc #32136
# Calling for doc #32137
# Calling for doc #32138
# Calling for doc #32139
# Calling for doc #32140
# Calling for doc #32141
# Calling for doc #32142
# Calling for doc #32143
# Token limit for doc #31873 exceeded, reducing the prompt size.
# Calling for doc #31873
# Token limit for doc #32071 exceeded, reducing the prompt size.
# Calling for doc #32071
# Token limit for doc #31857 exceeded, reducing the prompt size.
# Calling for doc #31857
# Calling for doc #32144
# Calling for doc #32145
# Calling for doc #32146
# Calling for doc #32147
# Calling for doc #32148
# Calling for doc #32149
# Calling for doc #32150
# Calling for doc #32151
# Calling for doc #32152
# Calling for doc #32153
# Calling for doc #32154
# Calling for doc #32155
# Calling for doc #32156
# Calling for doc #32157
# Calling for doc #32158
# Calling for doc #32159
# Calling for doc #32160
# Calling for doc #32161
# Calling for doc #32162
# Calling for doc #32163
# Calling for doc #32164
# Calling for doc #32165
# Token limit for doc #32132 exceeded, reducing the prompt size.
# Calling for doc #32132
# Calling for doc #32166
# Calling for doc #32167
# Calling for doc #32168
# Calling for doc #32169
# Calling for doc #32170
# Calling for doc #32171
# Calling for doc #32172
# Calling for doc #32173
# Calling for doc #32174
# Calling for doc #32175
# Calling for doc #32176
# Calling for doc #32177
# Calling for doc #32178
# Calling for doc #32179
# Calling for doc #32180
# Calling for doc #32181
# Calling for doc #32182
# Calling for doc #32183
# Calling for doc #32184
# Calling for doc #32185
# Calling for doc #32186
# Calling for doc #32187
# Calling for doc #32188
# Token limit for doc #31857 exceeded, reducing the prompt size.
# Calling for doc #31857
# Token limit for doc #32071 exceeded, reducing the prompt size.
# Calling for doc #32071
# Token limit for doc #31873 exceeded, reducing the prompt size.
# Calling for doc #31873
# Calling for doc #32189
# Token limit for doc #32132 exceeded, reducing the prompt size.
# Calling for doc #32132
# Calling for doc #32190
# Calling for doc #32191
# Calling for doc #32192
# Calling for doc #32193
# Calling for doc #32194
# Calling for doc #32195
# Calling for doc #32196
# Calling for doc #32197
# Calling for doc #32198
# Calling for doc #32199
# Calling for doc #32200
# Calling for doc #32201
# Calling for doc #32202
# Calling for doc #32203
# Calling for doc #32204
# Calling for doc #32205
# Calling for doc #32206
# Calling for doc #32207
# Calling for doc #32208
# Calling for doc #32209
# Calling for doc #32210
# Calling for doc #32211
# Calling for doc #32212
# Calling for doc #32213
# Calling for doc #32214
# Calling for doc #32215
# Calling for doc #32216
# Calling for doc #32217
# Calling for doc #32218
# Calling for doc #32219
# Calling for doc #32220
# Calling for doc #32221
# Calling for doc #32222
# Calling for doc #32223
# Calling for doc #32224
# Calling for doc #32225
# Calling for doc #32226
# Calling for doc #32227
# Calling for doc #32228
# Calling for doc #32229
# Calling for doc #32230
# Calling for doc #32231
# Calling for doc #32232
# Calling for doc #32233
# Calling for doc #32234
# Token limit for doc #31857 exceeded, reducing the prompt size.
# Calling for doc #31857
# Token limit for doc #32189 exceeded, reducing the prompt size.
# Calling for doc #32189
# Calling for doc #32235
# Token limit for doc #32132 exceeded, reducing the prompt size.
# Calling for doc #32132
# Token limit for doc #32071 exceeded, reducing the prompt size.
# Calling for doc #32071
# Calling for doc #32236
# Calling for doc #32237
# Calling for doc #32238
# Token limit for doc #32201 exceeded, reducing the prompt size.
# Calling for doc #32201
# Calling for doc #32239
# Calling for doc #32240
# Calling for doc #32241
# Token limit for doc #31857 exceeded, reducing the prompt size.
# Calling for doc #31857
# Calling for doc #32242
# Calling for doc #32243
# Calling for doc #32244
# Calling for doc #32245
# Calling for doc #32246
# Calling for doc #32247
# Calling for doc #32248
# Calling for doc #32249
# Token limit for doc #32189 exceeded, reducing the prompt size.
# Calling for doc #32189
# Calling for doc #32250
# Calling for doc #32251
# Calling for doc #32252
# Calling for doc #32253
# Calling for doc #32254
# Calling for doc #32255
# Calling for doc #32256
# Calling for doc #32257
# Calling for doc #32258
# Calling for doc #32259
# Calling for doc #32260
# Calling for doc #32261
# Calling for doc #32262
# Calling for doc #32263
# Calling for doc #32264
# Calling for doc #32265
# Calling for doc #32266
# Calling for doc #32267
# Calling for doc #32268
# Calling for doc #32269
# Calling for doc #32270
# Calling for doc #32271
# Calling for doc #32272
# Calling for doc #32273
# Calling for doc #32274
# Calling for doc #32275
# Calling for doc #32276
# Calling for doc #32277
# Calling for doc #32278
# Calling for doc #32279
# Token limit for doc #32071 exceeded, reducing the prompt size.
# Calling for doc #32071
# Calling for doc #32280
# Calling for doc #32281
# Calling for doc #32282
# Calling for doc #32283
# Calling for doc #32284
# Token limit for doc #32201 exceeded, reducing the prompt size.
# Calling for doc #32201
# Token limit for doc #32189 exceeded, reducing the prompt size.
# Calling for doc #32189
# Calling for doc #32285
# Calling for doc #32286
# Calling for doc #32287
# Calling for doc #32288
# Calling for doc #32289
# Calling for doc #32290
# Calling for doc #32291
# Calling for doc #32292
# Calling for doc #32293
# Calling for doc #32294
# Calling for doc #32295
# Calling for doc #32296
# Calling for doc #32297
# Calling for doc #32298
# Calling for doc #32299
# Calling for doc #32300
# Calling for doc #32301
# Calling for doc #32302
# Calling for doc #32303
# Calling for doc #32304
# Calling for doc #32305
# Calling for doc #32306
# Calling for doc #32307
# Calling for doc #32308
# Calling for doc #32309
# Calling for doc #32310
# Calling for doc #32311
# Calling for doc #32312
# Calling for doc #32313
# Calling for doc #32314
# Calling for doc #32315
# Calling for doc #32316
# Calling for doc #32317
# Calling for doc #32318
# Calling for doc #32319
# Calling for doc #32320
# Calling for doc #32321
# Calling for doc #32322
# Calling for doc #32323
# Calling for doc #32324
# Calling for doc #32325
# Calling for doc #32326
# Calling for doc #32327
# Calling for doc #32328
# Calling for doc #32329
# Calling for doc #32330
# Calling for doc #32331
# Calling for doc #32332
# Token limit for doc #32201 exceeded, reducing the prompt size.
# Calling for doc #32201
# Token limit for doc #32189 exceeded, reducing the prompt size.
# Calling for doc #32189
# Calling for doc #32333
# Calling for doc #32334
# Calling for doc #32335
# Calling for doc #32336
# Calling for doc #32337
# Calling for doc #32338
# Calling for doc #32339
# Calling for doc #32340
# Calling for doc #32341
# Calling for doc #32342
# Calling for doc #32343
# Calling for doc #32344
# Calling for doc #32345
# Calling for doc #32346
# Calling for doc #32347
# Calling for doc #32348
# Calling for doc #32349
# Calling for doc #32350
# Calling for doc #32351
# Calling for doc #32352
# Calling for doc #32353
# Calling for doc #32354
# Calling for doc #32355
# Calling for doc #32356
# Calling for doc #32357
# Calling for doc #32358
# Calling for doc #32359
# Calling for doc #32360
# Calling for doc #32361
# Calling for doc #32362
# Calling for doc #32363
# Calling for doc #32364
# Calling for doc #32365
# Calling for doc #32366
# Calling for doc #32367
# Calling for doc #32368
# Calling for doc #32369
# Calling for doc #32370
# Calling for doc #32371
# Calling for doc #32372
# Calling for doc #32373
# Calling for doc #32374
# Calling for doc #32375
# Calling for doc #32376
# Calling for doc #32377
# Calling for doc #32378
# Calling for doc #32379
# Token limit for doc #32189 exceeded, reducing the prompt size.
# Calling for doc #32189
# Token limit for doc #32201 exceeded, reducing the prompt size.
# Calling for doc #32201
# Calling for doc #32380
# Calling for doc #32381
# Token limit for doc #32189 exceeded, reducing the prompt size.
# Calling for doc #32189
# Token limit for doc #32201 exceeded, reducing the prompt size.
# Calling for doc #32201
# Calling for doc #32382
# Calling for doc #32383
# Calling for doc #32384
# Calling for doc #32385
# Calling for doc #32386
# Calling for doc #32387
# Calling for doc #32388
# Calling for doc #32389
# Calling for doc #32390
# Calling for doc #32391
# Calling for doc #32392
# Calling for doc #32393
# Calling for doc #32394
# Calling for doc #32395
# Calling for doc #32396
# Calling for doc #32397
# Calling for doc #32398
# Calling for doc #32399
# Calling for doc #32400
# Calling for doc #32401
# Calling for doc #32402
# Calling for doc #32403
# Calling for doc #32404
# Calling for doc #32405
# Calling for doc #32406
# Calling for doc #32407
# Calling for doc #32408
# Calling for doc #32409
# Calling for doc #32410
# Calling for doc #32411
# Calling for doc #32412
# Calling for doc #32413
# Calling for doc #32414
# Calling for doc #32415
# Calling for doc #32416
# Calling for doc #32417
# Calling for doc #32418
# Calling for doc #32419
# Calling for doc #32420
# Calling for doc #32421
# Calling for doc #32422
# Calling for doc #32423
# Calling for doc #32424
# Calling for doc #32425
# Calling for doc #32426
# Calling for doc #32427
# Calling for doc #32428
# Calling for doc #32429
# Token limit for doc #32201 exceeded, reducing the prompt size.
# Calling for doc #32201
# Calling for doc #32430
# Calling for doc #32431
# Calling for doc #32432
# Calling for doc #32433
# Calling for doc #32434
# Calling for doc #32435
# Calling for doc #32436
# Calling for doc #32437
# Calling for doc #32438
# Calling for doc #32439
# Calling for doc #32440
# Calling for doc #32441
# Calling for doc #32442
# Calling for doc #32443
# Calling for doc #32444
# Calling for doc #32445
# Calling for doc #32446
# Token limit for doc #32201 exceeded, reducing the prompt size.
# Calling for doc #32201
# Token limit for doc #32201 exceeded, reducing the prompt size.
# Calling for doc #32201

# %%
all_topics[-10:]
# Out:
# [['grb', 'optical', 'transient', 'a comment'],
#  ['a comment'],
#  ['ARU', 'infra-red', 'optical', 'gamma ray'],
#  ['neutrinos', 'agn', 'transient', 'puls'],
#  ['optical', 'gamma-ray burst'],
#  ['gev', 'gl', 'gamma-ray burst', 'optical', 'transient'],
#  ['gr deeds', 'celestial mechanics', 'transient', 'agn', 'black hole'],
#  ['gev', 'tev', 'vhe', 'neutrinos', 'transient'],
#  ['optical', 'gamma ray', 'gamma-ray burst', 'transient'],
#  ['iWitness', 'optical', 'gamma ray', 'gamma-ray burst']]

# %%
e = []
for i in all_topics:
    e+=i
    
len(set(e))
# Out:
# 10046

# %%
len(np.where(np.unique(e, return_counts=True)[1]>2)[0])
# Out:
# 766

# %%
gcn_df['topics'] = all_topics

# %%
gcn_df
# Out:
#                                                        body_clean  \
# telegram_index
# 31_gcn          s. v. zharikov v. v. sokolov sao ras yu. v. ba...
# 32_gcn          comparison optical r-band observations error b...
# 33_gcn          grb 980326 optical transient confirmed a. c. e...
# 34_gcn          bruce grossan robert knop saul perlmutter lawr...
# 35_gcn          addendum gcn 34 bruce grossan robert knop saul...
# ...                                                           ...
# 33636_gcn       we observed field grb 230414b d'ai et al. gcn ...
# 33637_gcn       we observed field grb230414b d'ai et al. gcn 3...
# 33633_gcn       on 2023-04-16 05 22 26.15 ut icecube detected ...
# 33634_gcn       we observed field grb 230414b swift trigger 11...
# 33635_gcn       on 2023-03-09 i observed field grb 230307a fer...
#
#                                                            topics
# telegram_index
# 31_gcn             [optical, gamma ray, gamma-ray burst, optical]
# 32_gcn             [optical, gamma-ray burst, transient, optical]
# 33_gcn                                   [## ro sg i g h ## nova]
# 34_gcn            [optical, gamma-ray burst, black hole, neutron]
# 35_gcn                                 [gev, cv, a comment, nova]
# ...                                                           ...
# 33636_gcn          [gev, gl, gamma-ray burst, optical, transient]
# 33637_gcn       [gr deeds, celestial mechanics, transient, agn...
# 33633_gcn                   [gev, tev, vhe, neutrinos, transient]
# 33634_gcn        [optical, gamma ray, gamma-ray burst, transient]
# 33635_gcn         [iWitness, optical, gamma ray, gamma-ray burst]
#
# [32447 rows x 2 columns]

# %% [markdown]
# ### Some topics are trash and some contain weird random values, clean them, and run the predicitons again if no topics left after the cleaning

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
gcn_df['topics'] = gcn_df['topics'].apply(str).apply(lambda x: re.sub(r'[^\w\s\-,]', ' ', x.lower()))
gcn_df['topics'] = gcn_df['topics'].apply(lambda x: x.split(','))
gcn_df['topics'] = gcn_df['topics'].apply(lambda x: [y.strip() for y in x if y.strip() 
                                                     and len(y.strip().split(' '))<3
                                                     and len(y.strip())>2])

# %%
benchmark_topics = np.unique(atel_df.explode('topics').apply(lambda x: x.topics.strip(), axis=1))

# %%
gcn_df['topics'] = gcn_df['topics'].apply(lambda x: [y for y in x if y in benchmark_topics])

# %%
gcn_df['len_topics'] = gcn_df['topics'].apply(len)

# %%
to_rerun = gcn_df[gcn_df.len_topics<2].copy()  # there should be at least 2 topics
to_accept = gcn_df[gcn_df.len_topics>=2].copy() 
len(to_rerun), len(to_accept)
# Out:
# (3465, 28982)

# %% [markdown]
# re-run topics extraction for these bodies

# %%
benchmark_topics
# Out:
# array(['a comment', 'agn', 'asteroid', 'asteroid  binary', 'binary',
#        'black hole', 'blazar', 'cataclysmic variable', 'comet',
#        'cosmic rays', 'direct collapse event', 'exoplanet',
#        'far-infra-red', 'fast radio burst', 'gamma ray',
#        'gamma-ray burst', 'gev', 'globular cluster',
#        'gravitational lensing', 'gravitational waves', 'infra-red',
#        'magnetar', 'meteor', 'microlensing event', 'millimeter',
#        'near-earth object', 'neutrinos', 'neutron star', 'nova',
#        'optical', 'planet', 'planet  minor',
#        'potentially hazardous asteroid', 'pre-main-sequence star',
#        'pulsar', 'quasar', 'radio', 'request for observations',
#        'soft gamma-ray repeater', 'solar system object', 'star',
#        'sub-millimeter', 'supernova remnant', 'supernovae', 'tev',
#        'the sun', 'tidal disruption event', 'transient', 'uhe',
#        'ultra-violet', 'variables', 'vhe', 'x-ray',
#        'young stellar object'], dtype=object)

# %%
good_enough = []

for i, body in enumerate(to_rerun.body_clean):
    
    gen_topics = await call_one(body, i)
    gen_topics = validate_topics(gen_topics)
    
    while not gen_topics:
        gen_topics = await call_one(body, i)
        gen_topics = validate_topics(gen_topics)

    good_enough.append(gen_topics)
# Out:
# Calling for doc #0
# Calling for doc #1
# Calling for doc #2
# Calling for doc #3
# Calling for doc #4
# Calling for doc #5
# Calling for doc #6
# Calling for doc #7
# Calling for doc #8
# Calling for doc #9
# Calling for doc #10
# Calling for doc #11
# Calling for doc #12
# Calling for doc #13
# Calling for doc #14
# Calling for doc #15
# Calling for doc #16
# Calling for doc #17
# Calling for doc #18
# Calling for doc #18
# Calling for doc #19
# Calling for doc #20
# Calling for doc #21
# Calling for doc #22
# Calling for doc #23
# Calling for doc #24
# Calling for doc #24
# Calling for doc #25
# Calling for doc #26
# Calling for doc #27
# Calling for doc #28
# Calling for doc #29
# Calling for doc #29
# Calling for doc #30
# Calling for doc #31
# Calling for doc #32
# Calling for doc #33
# Calling for doc #34
# Calling for doc #35
# Calling for doc #36
# Calling for doc #37
# Calling for doc #38
# Calling for doc #39
# Calling for doc #39
# Calling for doc #40
# Calling for doc #41
# Calling for doc #41
# Calling for doc #42
# Calling for doc #42
# Calling for doc #43
# Calling for doc #44
# Calling for doc #45
# Calling for doc #46
# Calling for doc #47
# Calling for doc #48
# Calling for doc #49
# Calling for doc #49
# Calling for doc #50
# Calling for doc #51
# Calling for doc #52
# Calling for doc #53
# Calling for doc #53
# Calling for doc #54
# Calling for doc #55
# Calling for doc #56
# Calling for doc #57
# Calling for doc #58
# Calling for doc #59
# Calling for doc #60
# Calling for doc #61
# Calling for doc #62
# Calling for doc #63
# Calling for doc #63
# Calling for doc #64
# Calling for doc #64
# Calling for doc #65
# Calling for doc #66
# Calling for doc #66
# Calling for doc #66
# Calling for doc #67
# Calling for doc #68
# Calling for doc #69
# Calling for doc #70
# Calling for doc #71
# Calling for doc #72
# Calling for doc #73
# Calling for doc #74
# Calling for doc #75
# Calling for doc #76
# Calling for doc #76
# Calling for doc #77
# Calling for doc #78
# Calling for doc #79
# Calling for doc #80
# Calling for doc #81
# Calling for doc #81
# Calling for doc #81
# Calling for doc #82
# Calling for doc #83
# Calling for doc #84
# Calling for doc #85
# Calling for doc #86
# Calling for doc #87
# Calling for doc #87
# Calling for doc #88
# Calling for doc #89
# Calling for doc #90
# Calling for doc #90
# Calling for doc #91
# Calling for doc #92
# Calling for doc #93
# Calling for doc #94
# Calling for doc #95
# Calling for doc #96
# Calling for doc #97
# Calling for doc #98
# Calling for doc #99
# Calling for doc #100
# Calling for doc #100
# Calling for doc #100
# Calling for doc #101
# Calling for doc #102
# Calling for doc #103
# Calling for doc #104
# Calling for doc #105
# Calling for doc #105
# Calling for doc #106
# Calling for doc #107
# Calling for doc #108
# Calling for doc #109
# Calling for doc #110
# Calling for doc #110
# Calling for doc #110
# Calling for doc #110
# Calling for doc #111
# Calling for doc #112
# Calling for doc #113
# Calling for doc #114
# Calling for doc #115
# Calling for doc #115
# Calling for doc #116
# Calling for doc #116
# Calling for doc #117
# Calling for doc #118
# Calling for doc #119
# Calling for doc #120
# Calling for doc #121
# Calling for doc #122
# Calling for doc #122
# Calling for doc #123
# Calling for doc #124
# Calling for doc #125
# Calling for doc #126
# Calling for doc #127
# Calling for doc #128
# Calling for doc #128
# Calling for doc #129
# Calling for doc #130
# Calling for doc #130
# Calling for doc #131
# Calling for doc #132
# Calling for doc #133
# Calling for doc #134
# Calling for doc #135
# Calling for doc #136
# Calling for doc #136
# Calling for doc #136
# Calling for doc #137
# Calling for doc #138
# Calling for doc #139
# Calling for doc #140
# Calling for doc #141
# Calling for doc #142
# Calling for doc #142
# Calling for doc #143
# Calling for doc #144
# Calling for doc #145
# Calling for doc #146
# Calling for doc #147
# Calling for doc #148
# Calling for doc #149
# Calling for doc #150
# Calling for doc #151
# Calling for doc #152
# Calling for doc #153
# Calling for doc #154
# Calling for doc #155
# Calling for doc #156
# Calling for doc #156
# Calling for doc #156
# Calling for doc #157
# Calling for doc #158
# Calling for doc #158
# Calling for doc #159
# Calling for doc #160
# Calling for doc #161
# Calling for doc #162
# Calling for doc #163
# Calling for doc #163
# Calling for doc #164
# Calling for doc #165
# Calling for doc #166
# Calling for doc #167
# Calling for doc #168
# Calling for doc #169
# Calling for doc #170
# Calling for doc #171
# Calling for doc #172
# Calling for doc #173
# Calling for doc #174
# Calling for doc #175
# Calling for doc #176
# Calling for doc #177
# Calling for doc #178
# Calling for doc #179
# Calling for doc #179
# Calling for doc #180
# Calling for doc #181
# Calling for doc #181
# Calling for doc #182
# Calling for doc #183
# Calling for doc #183
# Calling for doc #184
# Calling for doc #185
# Calling for doc #186
# Calling for doc #187
# Calling for doc #188
# Calling for doc #189
# Calling for doc #190
# Calling for doc #191
# Token limit for doc #191 exceeded, reducing the prompt size.
# Calling for doc #191
# Calling for doc #191
# Token limit for doc #191 exceeded, reducing the prompt size.
# Calling for doc #191
# Calling for doc #192
# Calling for doc #192
# Calling for doc #193
# Calling for doc #194
# Calling for doc #195
# Calling for doc #195
# Calling for doc #196
# Calling for doc #197
# Calling for doc #197
# Calling for doc #198
# Calling for doc #198
# Calling for doc #199
# Calling for doc #200
# Calling for doc #200
# Calling for doc #201
# Calling for doc #202
# Calling for doc #202
# Calling for doc #202
# Calling for doc #202
# Calling for doc #202
# Calling for doc #203
# Calling for doc #204
# Calling for doc #205
# Calling for doc #205
# Calling for doc #206
# Calling for doc #207
# Calling for doc #208
# Calling for doc #209
# Calling for doc #210
# Calling for doc #211
# Calling for doc #212
# Calling for doc #212
# Calling for doc #212
# Calling for doc #212
# Calling for doc #213
# Calling for doc #214
# Calling for doc #214
# Calling for doc #215
# Calling for doc #216
# Calling for doc #217
# Calling for doc #218
# Calling for doc #219
# Calling for doc #220
# Calling for doc #221
# Calling for doc #222
# Calling for doc #223
# Calling for doc #223
# Calling for doc #224
# Calling for doc #224
# Calling for doc #224
# Calling for doc #225
# Calling for doc #226
# Calling for doc #227
# Calling for doc #228
# Calling for doc #229
# Calling for doc #229
# Calling for doc #229
# Calling for doc #229
# Calling for doc #229
# Calling for doc #229
# Calling for doc #229
# Calling for doc #229
# Calling for doc #229
# Calling for doc #230
# Calling for doc #231
# Calling for doc #232
# Calling for doc #233
# Calling for doc #234
# Calling for doc #235
# Calling for doc #235
# Calling for doc #236
# Calling for doc #237
# Calling for doc #238
# Calling for doc #238
# Calling for doc #239
# Calling for doc #239
# Calling for doc #240
# Calling for doc #241
# Calling for doc #242
# Calling for doc #243
# Calling for doc #244
# Calling for doc #245
# Calling for doc #246
# Calling for doc #247
# Calling for doc #248
# Calling for doc #249
# Calling for doc #250
# Calling for doc #251
# Calling for doc #252
# Calling for doc #253
# Calling for doc #254
# Calling for doc #255
# Calling for doc #256
# Calling for doc #257
# Calling for doc #258
# Calling for doc #259
# Calling for doc #260
# Calling for doc #261
# Calling for doc #262
# Calling for doc #263
# Calling for doc #264
# Calling for doc #265
# Calling for doc #265
# Calling for doc #266
# Calling for doc #266
# Calling for doc #267
# Calling for doc #268
# Calling for doc #269
# Calling for doc #270
# Calling for doc #271
# Calling for doc #272
# Calling for doc #273
# Calling for doc #274
# Calling for doc #275
# Calling for doc #276
# Calling for doc #276
# Calling for doc #277
# Calling for doc #278
# Calling for doc #279
# Calling for doc #280
# Calling for doc #281
# Calling for doc #282
# Calling for doc #283
# Calling for doc #284
# Calling for doc #285
# Calling for doc #286
# Calling for doc #287
# Calling for doc #288
# Calling for doc #288
# Calling for doc #288
# Calling for doc #289
# Calling for doc #290
# Calling for doc #290
# Calling for doc #290
# Calling for doc #290
# Calling for doc #290
# Calling for doc #290
# Calling for doc #290
# Calling for doc #290
# Calling for doc #291
# Calling for doc #292
# Calling for doc #293
# Calling for doc #294
# Calling for doc #295
# Calling for doc #296
# Calling for doc #297
# Calling for doc #297
# Calling for doc #298
# Calling for doc #299
# Calling for doc #300
# Calling for doc #301
# Calling for doc #301
# Calling for doc #301
# Calling for doc #302
# Calling for doc #303
# Calling for doc #303
# Calling for doc #304
# Calling for doc #305
# Calling for doc #306
# Calling for doc #307
# Calling for doc #308
# Calling for doc #309
# Calling for doc #310
# Calling for doc #311
# Calling for doc #312
# Calling for doc #313
# Calling for doc #314
# Calling for doc #315
# Calling for doc #316
# Calling for doc #317
# Calling for doc #318
# Calling for doc #319
# Calling for doc #320
# Calling for doc #321
# Calling for doc #322
# Calling for doc #323
# Calling for doc #324
# Calling for doc #324
# Calling for doc #324
# Calling for doc #325
# Calling for doc #325
# Calling for doc #326
# Calling for doc #326
# Calling for doc #327
# Calling for doc #328
# Calling for doc #328
# Calling for doc #329
# Calling for doc #330
# Calling for doc #331
# Calling for doc #332
# Calling for doc #333
# Calling for doc #334
# Calling for doc #335
# Calling for doc #336
# Calling for doc #336
# Calling for doc #337
# Calling for doc #337
# Calling for doc #338
# Calling for doc #339
# Calling for doc #339
# Calling for doc #340
# Calling for doc #341
# Calling for doc #342
# Calling for doc #343
# Calling for doc #343
# Calling for doc #344
# Calling for doc #344
# Calling for doc #345
# Calling for doc #346
# Calling for doc #347
# Calling for doc #348
# Calling for doc #349
# Calling for doc #350
# Calling for doc #351
# Calling for doc #352
# Calling for doc #352
# Calling for doc #353
# Calling for doc #354
# Calling for doc #355
# Calling for doc #356
# Calling for doc #357
# Calling for doc #358
# Calling for doc #358
# Calling for doc #359
# Calling for doc #360
# Calling for doc #360
# Calling for doc #361
# Calling for doc #362
# Calling for doc #362
# Calling for doc #363
# Calling for doc #364
# Calling for doc #364
# Calling for doc #364
# Calling for doc #365
# Calling for doc #366
# Calling for doc #367
# Calling for doc #368
# Calling for doc #369
# Calling for doc #370
# Calling for doc #371
# Calling for doc #371
# Calling for doc #372
# Calling for doc #372
# Calling for doc #372
# Calling for doc #372
# Calling for doc #372
# Calling for doc #372
# Calling for doc #372
# Calling for doc #372
# Calling for doc #372
# Calling for doc #372
# Calling for doc #373
# Calling for doc #374
# Calling for doc #374
# Calling for doc #375
# Calling for doc #376
# Calling for doc #377
# Calling for doc #377
# Calling for doc #378
# Calling for doc #378
# Calling for doc #378
# Calling for doc #379
# Calling for doc #380
# Calling for doc #381
# Calling for doc #382
# Calling for doc #383
# Calling for doc #384
# Calling for doc #385
# Calling for doc #386
# Calling for doc #387
# Calling for doc #387
# Calling for doc #387
# Calling for doc #387
# Calling for doc #388
# Calling for doc #389
# Calling for doc #390
# Calling for doc #390
# Calling for doc #391
# Calling for doc #391
# Calling for doc #392
# Calling for doc #393
# Calling for doc #394
# Calling for doc #395
# Calling for doc #395
# Calling for doc #396
# Calling for doc #397
# Calling for doc #398
# Calling for doc #399
# Calling for doc #400
# Calling for doc #401
# Calling for doc #402
# Calling for doc #403
# Calling for doc #403
# Calling for doc #403
# Calling for doc #404
# Calling for doc #404
# Calling for doc #405
# Calling for doc #406
# Calling for doc #407
# Calling for doc #408
# Calling for doc #409
# Calling for doc #410
# Calling for doc #411
# Calling for doc #412
# Calling for doc #413
# Calling for doc #414
# Calling for doc #415
# Calling for doc #415
# Calling for doc #416
# Calling for doc #417
# Calling for doc #418
# Calling for doc #418
# Calling for doc #419
# Calling for doc #419
# Calling for doc #419
# Calling for doc #420
# Calling for doc #421
# Calling for doc #422
# Calling for doc #423
# Calling for doc #424
# Calling for doc #425
# Calling for doc #426
# Calling for doc #427
# Calling for doc #428
# Calling for doc #429
# Calling for doc #430
# Calling for doc #431
# Calling for doc #432
# Calling for doc #432
# Calling for doc #433
# Calling for doc #434
# Calling for doc #434
# Calling for doc #435
# Calling for doc #435
# Calling for doc #436
# Calling for doc #437
# Calling for doc #438
# Calling for doc #439
# Calling for doc #440
# Calling for doc #441
# Calling for doc #441
# Calling for doc #442
# Calling for doc #443
# Calling for doc #444
# Calling for doc #445
# Calling for doc #445
# Calling for doc #445
# Calling for doc #446
# Calling for doc #446
# Calling for doc #446
# Calling for doc #446
# Calling for doc #447
# Calling for doc #448
# Calling for doc #449
# Calling for doc #450
# Calling for doc #451
# Calling for doc #452
# Calling for doc #453
# Calling for doc #454
# Calling for doc #455
# Calling for doc #456
# Calling for doc #457
# Calling for doc #458
# Calling for doc #459
# Calling for doc #459
# Calling for doc #459
# Calling for doc #460
# Calling for doc #460
# Calling for doc #460
# Calling for doc #460
# Calling for doc #460
# Calling for doc #460
# Calling for doc #460
# Calling for doc #460
# Calling for doc #460
# Calling for doc #461
# Calling for doc #462
# Calling for doc #463
# Calling for doc #464
# Calling for doc #465
# Calling for doc #466
# Calling for doc #466
# Calling for doc #466
# Calling for doc #467
# Calling for doc #468
# Calling for doc #469
# Calling for doc #470
# Calling for doc #471
# Calling for doc #471
# Calling for doc #472
# Calling for doc #473
# Calling for doc #474
# Calling for doc #475
# Calling for doc #476
# Calling for doc #477
# Calling for doc #477
# Calling for doc #478
# Calling for doc #479
# Calling for doc #480
# Calling for doc #481
# Calling for doc #482
# Calling for doc #483
# Calling for doc #484
# Calling for doc #485
# Calling for doc #486
# Calling for doc #487
# Calling for doc #488
# Calling for doc #489
# Calling for doc #489
# Calling for doc #489
# Calling for doc #489
# Calling for doc #489
# Calling for doc #489
# Calling for doc #489
# Calling for doc #490
# Calling for doc #491
# Calling for doc #492
# Calling for doc #493
# Calling for doc #494
# Calling for doc #495
# Calling for doc #496
# Calling for doc #497
# Calling for doc #498
# Calling for doc #499
# Calling for doc #500
# Calling for doc #501
# Calling for doc #502
# Calling for doc #503
# Calling for doc #504
# Calling for doc #505
# Calling for doc #505
# Calling for doc #506
# Calling for doc #507
# Calling for doc #508
# Calling for doc #509
# Calling for doc #510
# Calling for doc #511
# Calling for doc #512
# Calling for doc #513
# Calling for doc #514
# Calling for doc #515
# Calling for doc #516
# Calling for doc #517
# Calling for doc #518
# Calling for doc #519
# Calling for doc #520
# Calling for doc #521
# Calling for doc #522
# Calling for doc #523
# Calling for doc #523
# Calling for doc #524
# Calling for doc #525
# Calling for doc #526
# Calling for doc #527
# Calling for doc #528
# Calling for doc #529
# Calling for doc #530
# Calling for doc #531
# Calling for doc #532
# Calling for doc #533
# Calling for doc #534
# Calling for doc #535
# Calling for doc #536
# Calling for doc #536
# Calling for doc #537
# Calling for doc #538
# Calling for doc #539
# Calling for doc #540
# Calling for doc #541
# Calling for doc #541
# Calling for doc #542
# Calling for doc #543
# Calling for doc #544
# Calling for doc #545
# Calling for doc #546
# Calling for doc #547
# Calling for doc #548
# Calling for doc #549
# Calling for doc #550
# Calling for doc #550
# Calling for doc #551
# Calling for doc #552
# Calling for doc #553
# Calling for doc #554
# Calling for doc #555
# Calling for doc #556
# Calling for doc #557
# Calling for doc #558
# Calling for doc #559
# Calling for doc #560
# Calling for doc #561
# Calling for doc #562
# Calling for doc #563
# Calling for doc #564
# Calling for doc #565
# Calling for doc #566
# Calling for doc #567
# Calling for doc #568
# Calling for doc #568
# Calling for doc #569
# Calling for doc #570
# Calling for doc #571
# Calling for doc #572
# Calling for doc #573
# Calling for doc #574
# Calling for doc #575
# Calling for doc #576
# Calling for doc #577
# Calling for doc #578
# Calling for doc #579
# Calling for doc #580
# Calling for doc #581
# Calling for doc #582
# Calling for doc #583
# Calling for doc #584
# Calling for doc #585
# Calling for doc #586
# Calling for doc #587
# Calling for doc #587
# Calling for doc #587
# Calling for doc #588
# Calling for doc #589
# Calling for doc #590
# Calling for doc #591
# Calling for doc #591
# Calling for doc #592
# Calling for doc #593
# Calling for doc #594
# Calling for doc #595
# Calling for doc #595
# Calling for doc #596
# Calling for doc #597
# Calling for doc #598
# Calling for doc #599
# Calling for doc #600
# Calling for doc #601
# Calling for doc #602
# Calling for doc #603
# Calling for doc #603
# Calling for doc #603
# Calling for doc #604
# Calling for doc #604
# Calling for doc #605
# Calling for doc #605
# Calling for doc #605
# Calling for doc #606
# Calling for doc #607
# Calling for doc #608
# Calling for doc #609
# Calling for doc #609
# Calling for doc #610
# Calling for doc #611
# Calling for doc #612
# Calling for doc #612
# Calling for doc #612
# Calling for doc #612
# Calling for doc #613
# Calling for doc #614
# Calling for doc #615
# Calling for doc #616
# Calling for doc #617
# Calling for doc #618
# Calling for doc #619
# Calling for doc #620
# Calling for doc #621
# Calling for doc #622
# Calling for doc #623
# Calling for doc #624
# Calling for doc #625
# Calling for doc #625
# Calling for doc #626
# Calling for doc #627
# Calling for doc #627
# Calling for doc #627
# Calling for doc #628
# Calling for doc #629
# Calling for doc #630
# Calling for doc #630
# Calling for doc #631
# Calling for doc #632
# Calling for doc #633
# Calling for doc #634
# Calling for doc #635
# Calling for doc #636
# Calling for doc #637
# Calling for doc #637
# Calling for doc #638
# Calling for doc #639
# Calling for doc #640
# Calling for doc #641
# Calling for doc #642
# Calling for doc #643
# Calling for doc #644
# Calling for doc #645
# Calling for doc #646
# Calling for doc #647
# Calling for doc #648
# Calling for doc #648
# Calling for doc #649
# Calling for doc #650
# Calling for doc #650
# Calling for doc #650
# Calling for doc #651
# Calling for doc #652
# Calling for doc #653
# Calling for doc #654
# Calling for doc #655
# Calling for doc #656
# Calling for doc #656
# Calling for doc #657
# Calling for doc #658
# Calling for doc #659
# Calling for doc #660
# Calling for doc #661
# Calling for doc #662
# Calling for doc #663
# Calling for doc #664
# Calling for doc #665
# Calling for doc #666
# Calling for doc #667
# Calling for doc #668
# Calling for doc #669
# Calling for doc #669
# Calling for doc #670
# Calling for doc #670
# Calling for doc #671
# Calling for doc #672
# Calling for doc #673
# Calling for doc #674
# Calling for doc #674
# Calling for doc #675
# Calling for doc #676
# Calling for doc #677
# Calling for doc #678
# Calling for doc #679
# Calling for doc #679
# Calling for doc #679
# Calling for doc #679
# Calling for doc #679
# Calling for doc #680
# Calling for doc #681
# Calling for doc #681
# Calling for doc #682
# Calling for doc #683
# Calling for doc #684
# Calling for doc #685
# Calling for doc #686
# Calling for doc #686
# Calling for doc #687
# Calling for doc #688
# Calling for doc #689
# Calling for doc #690
# Calling for doc #691
# Calling for doc #691
# Calling for doc #691
# Calling for doc #691
# Calling for doc #691
# Calling for doc #692
# Calling for doc #693
# Calling for doc #694
# Calling for doc #695
# Calling for doc #695
# Calling for doc #696
# Calling for doc #697
# Calling for doc #698
# Calling for doc #699
# Calling for doc #700
# Calling for doc #701
# Calling for doc #702
# Calling for doc #703
# Calling for doc #704
# Calling for doc #705
# Calling for doc #706
# Calling for doc #707
# Calling for doc #708
# Calling for doc #709
# Calling for doc #709
# Calling for doc #710
# Calling for doc #711
# Calling for doc #712
# Calling for doc #713
# Calling for doc #714
# Calling for doc #715
# Calling for doc #715
# Calling for doc #715
# Calling for doc #716
# Calling for doc #717
# Calling for doc #717
# Calling for doc #718
# Calling for doc #719
# Calling for doc #720
# Calling for doc #721
# Calling for doc #722
# Calling for doc #723
# Calling for doc #724
# Calling for doc #725
# Calling for doc #725
# Calling for doc #726
# Calling for doc #727
# Calling for doc #728
# Calling for doc #728
# Calling for doc #729
# Calling for doc #730
# Calling for doc #731
# Calling for doc #732
# Calling for doc #733
# Calling for doc #734
# Calling for doc #735
# Calling for doc #735
# Calling for doc #736
# Calling for doc #737
# Calling for doc #738
# Calling for doc #738
# Calling for doc #739
# Calling for doc #740
# Calling for doc #741
# Calling for doc #742
# Calling for doc #743
# Calling for doc #744
# Calling for doc #745
# Calling for doc #746
# Calling for doc #747
# Calling for doc #748
# Calling for doc #749
# Calling for doc #750
# Calling for doc #751
# Calling for doc #752
# Calling for doc #753
# Calling for doc #753
# Calling for doc #754
# Calling for doc #755
# Calling for doc #756
# Calling for doc #757
# Calling for doc #758
# Calling for doc #759
# Calling for doc #760
# Calling for doc #761
# Calling for doc #762
# Calling for doc #763
# Calling for doc #764
# Calling for doc #765
# Calling for doc #765
# Calling for doc #766
# Calling for doc #767
# Calling for doc #768
# Calling for doc #768
# Calling for doc #769
# Calling for doc #770
# Calling for doc #771
# Calling for doc #772
# Calling for doc #773
# Calling for doc #774
# Calling for doc #775
# Calling for doc #776
# Calling for doc #777
# Calling for doc #777
# Calling for doc #777
# Calling for doc #778
# Calling for doc #779
# Calling for doc #780
# Calling for doc #781
# Calling for doc #782
# Calling for doc #783
# Calling for doc #784
# Calling for doc #785
# Calling for doc #786
# Calling for doc #786
# Calling for doc #786
# Calling for doc #787
# Calling for doc #788
# Calling for doc #789
# Calling for doc #790
# Calling for doc #791
# Calling for doc #792
# Calling for doc #793
# Calling for doc #794
# Calling for doc #795
# Calling for doc #796
# Calling for doc #797
# Calling for doc #798
# Calling for doc #799
# Calling for doc #800
# Calling for doc #800
# Calling for doc #800
# Calling for doc #801
# Calling for doc #802
# Calling for doc #802
# Calling for doc #803
# Calling for doc #804
# Calling for doc #804
# Calling for doc #805
# Calling for doc #806
# Calling for doc #807
# Calling for doc #807
# Calling for doc #808
# Calling for doc #809
# Calling for doc #809
# Calling for doc #810
# Calling for doc #811
# Calling for doc #812
# Calling for doc #813
# Calling for doc #814
# Calling for doc #815
# Calling for doc #816
# Calling for doc #817
# Calling for doc #817
# Calling for doc #818
# Calling for doc #818
# Calling for doc #818
# Calling for doc #818
# Calling for doc #818
# Calling for doc #819
# Calling for doc #820
# Calling for doc #821
# Calling for doc #822
# Calling for doc #823
# Calling for doc #824
# Calling for doc #824
# Calling for doc #824
# Calling for doc #825
# Calling for doc #826
# Calling for doc #827
# Calling for doc #828
# Calling for doc #828
# Calling for doc #829
# Calling for doc #830
# Calling for doc #831
# Calling for doc #832
# Calling for doc #833
# Calling for doc #834
# Calling for doc #835
# Calling for doc #836
# Calling for doc #836
# Calling for doc #836
# Calling for doc #837
# Calling for doc #837
# Calling for doc #838
# Calling for doc #839
# Calling for doc #840
# Calling for doc #840
# Calling for doc #840
# Calling for doc #841
# Calling for doc #842
# Calling for doc #843
# Calling for doc #844
# Calling for doc #845
# Calling for doc #846
# Calling for doc #847
# Calling for doc #848
# Calling for doc #849
# Calling for doc #850
# Calling for doc #851
# Calling for doc #852
# Calling for doc #853
# Calling for doc #854
# Calling for doc #855
# Calling for doc #856
# Calling for doc #857
# Calling for doc #858
# Calling for doc #858
# Calling for doc #859
# Calling for doc #860
# Calling for doc #861
# Calling for doc #862
# Calling for doc #863
# Calling for doc #864
# Calling for doc #865
# Calling for doc #866
# Calling for doc #867
# Calling for doc #868
# Calling for doc #869
# Calling for doc #870
# Calling for doc #871
# Calling for doc #872
# Calling for doc #873
# Calling for doc #874
# Calling for doc #875
# Calling for doc #876
# Calling for doc #877
# Calling for doc #878
# Calling for doc #879
# Calling for doc #880
# Calling for doc #881
# Calling for doc #882
# Calling for doc #883
# Calling for doc #884
# Calling for doc #885
# Calling for doc #886
# Calling for doc #887
# Calling for doc #888
# Calling for doc #889
# Calling for doc #890
# Calling for doc #890
# Calling for doc #891
# Calling for doc #892
# Calling for doc #892
# Calling for doc #892
# Calling for doc #892
# Calling for doc #892
# Calling for doc #893
# Calling for doc #894
# Calling for doc #895
# Calling for doc #895
# Calling for doc #896
# Calling for doc #896
# Calling for doc #896
# Calling for doc #897
# Calling for doc #898
# Calling for doc #899
# Calling for doc #900
# Calling for doc #901
# Calling for doc #902
# Calling for doc #902
# Calling for doc #903
# Calling for doc #903
# Calling for doc #903
# Calling for doc #904
# Calling for doc #904
# Calling for doc #904
# Calling for doc #905
# Calling for doc #906
# Calling for doc #906
# Calling for doc #907
# Calling for doc #907
# Calling for doc #907
# Calling for doc #908
# Calling for doc #909
# Calling for doc #910
# Calling for doc #911
# Calling for doc #912
# Calling for doc #913
# Calling for doc #914
# Calling for doc #915
# Calling for doc #916
# Calling for doc #917
# Calling for doc #918
# Calling for doc #919
# Calling for doc #920
# Calling for doc #921
# Calling for doc #922
# Calling for doc #923
# Calling for doc #923
# Calling for doc #924
# Calling for doc #925
# Calling for doc #926
# Calling for doc #927
# Calling for doc #927
# Calling for doc #928
# Calling for doc #929
# Calling for doc #930
# Calling for doc #931
# Calling for doc #931
# Calling for doc #931
# Calling for doc #931
# Calling for doc #932
# Calling for doc #933
# Calling for doc #934
# Calling for doc #935
# Calling for doc #936
# Calling for doc #937
# Calling for doc #937
# Calling for doc #938
# Calling for doc #938
# Calling for doc #939
# Calling for doc #940
# Calling for doc #940
# Calling for doc #941
# Calling for doc #941
# Calling for doc #942
# Calling for doc #943
# Calling for doc #943
# Calling for doc #944
# Calling for doc #945
# Calling for doc #946
# Calling for doc #947
# Calling for doc #947
# Calling for doc #948
# Calling for doc #949
# Calling for doc #949
# Calling for doc #950
# Calling for doc #951
# Calling for doc #952
# Calling for doc #953
# Calling for doc #954
# Calling for doc #955
# Calling for doc #955
# Calling for doc #956
# Calling for doc #957
# Calling for doc #958
# Calling for doc #959
# Calling for doc #960
# Calling for doc #961
# Calling for doc #962
# Calling for doc #963
# Calling for doc #964
# Calling for doc #965
# Calling for doc #965
# Calling for doc #966
# Calling for doc #967
# Calling for doc #968
# Calling for doc #969
# Calling for doc #970
# Calling for doc #971
# Calling for doc #972
# Calling for doc #972
# Calling for doc #972
# Calling for doc #972
# Calling for doc #972
# Calling for doc #973
# Calling for doc #974
# Calling for doc #975
# Calling for doc #975
# Calling for doc #976
# Calling for doc #976
# Calling for doc #977
# Calling for doc #978
# Calling for doc #979
# Calling for doc #980
# Calling for doc #981
# Calling for doc #981
# Calling for doc #982
# Calling for doc #983
# Calling for doc #984
# Calling for doc #985
# Calling for doc #986
# Calling for doc #986
# Calling for doc #987
# Calling for doc #988
# Calling for doc #989
# Calling for doc #990
# Calling for doc #991
# Calling for doc #992
# Calling for doc #993
# Calling for doc #994
# Calling for doc #995
# Calling for doc #996
# Calling for doc #997
# Calling for doc #998
# Calling for doc #998
# Calling for doc #998
# Calling for doc #998
# Calling for doc #998
# Calling for doc #998
# Calling for doc #999
# Calling for doc #1000
# Calling for doc #1001
# Calling for doc #1001
# Calling for doc #1002
# Calling for doc #1002
# Calling for doc #1003
# Calling for doc #1004
# Calling for doc #1005
# Calling for doc #1006
# Calling for doc #1007
# Calling for doc #1008
# Calling for doc #1009
# Calling for doc #1010
# Calling for doc #1011
# Calling for doc #1012
# Calling for doc #1013
# Calling for doc #1014
# Calling for doc #1014
# Calling for doc #1014
# Calling for doc #1015
# Calling for doc #1016
# Calling for doc #1017
# Calling for doc #1017
# Calling for doc #1018
# Calling for doc #1018
# Calling for doc #1019
# Calling for doc #1020
# Calling for doc #1021
# Calling for doc #1022
# Calling for doc #1022
# Calling for doc #1022
# Calling for doc #1023
# Calling for doc #1023
# Calling for doc #1024
# Calling for doc #1025
# Calling for doc #1026
# Calling for doc #1027
# Calling for doc #1027
# Calling for doc #1028
# Calling for doc #1028
# Calling for doc #1028
# Calling for doc #1029
# Calling for doc #1030
# Calling for doc #1031
# Calling for doc #1032
# Calling for doc #1032
# Calling for doc #1032
# Calling for doc #1033
# Calling for doc #1034
# Calling for doc #1035
# Calling for doc #1035
# Calling for doc #1035
# Calling for doc #1036
# Calling for doc #1036
# Calling for doc #1037
# Calling for doc #1038
# Calling for doc #1039
# Calling for doc #1040
# Calling for doc #1041
# Calling for doc #1041
# Calling for doc #1041
# Calling for doc #1042
# Calling for doc #1043
# Calling for doc #1043
# Calling for doc #1044
# Calling for doc #1045
# Calling for doc #1046
# Calling for doc #1047
# Calling for doc #1048
# Calling for doc #1048
# Calling for doc #1049
# Calling for doc #1050
# Calling for doc #1051
# Calling for doc #1052
# Calling for doc #1052
# Calling for doc #1053
# Calling for doc #1054
# Calling for doc #1055
# Calling for doc #1056
# Calling for doc #1057
# Calling for doc #1058
# Calling for doc #1059
# Calling for doc #1060
# Calling for doc #1061
# Calling for doc #1062
# Calling for doc #1062
# Calling for doc #1063
# Calling for doc #1063
# Calling for doc #1064
# Calling for doc #1065
# Calling for doc #1066
# Calling for doc #1067
# Calling for doc #1068
# Calling for doc #1069
# Calling for doc #1070
# Calling for doc #1071
# Calling for doc #1072
# Calling for doc #1073
# Calling for doc #1074
# Calling for doc #1075
# Calling for doc #1075
# Calling for doc #1076
# Calling for doc #1077
# Calling for doc #1077
# Calling for doc #1077
# Calling for doc #1077
# Calling for doc #1077
# Calling for doc #1077
# Calling for doc #1077
# Calling for doc #1077
# Calling for doc #1077
# Calling for doc #1078
# Calling for doc #1079
# Calling for doc #1079
# Calling for doc #1079
# Calling for doc #1080
# Calling for doc #1081
# Calling for doc #1081
# Calling for doc #1081
# Calling for doc #1081
# Calling for doc #1082
# Calling for doc #1083
# Calling for doc #1083
# Calling for doc #1084
# Calling for doc #1085
# Calling for doc #1086
# Calling for doc #1087
# Calling for doc #1088
# Calling for doc #1088
# Calling for doc #1089
# Calling for doc #1090
# Calling for doc #1090
# Calling for doc #1090
# Calling for doc #1091
# Calling for doc #1092
# Calling for doc #1093
# Calling for doc #1094
# Calling for doc #1094
# Calling for doc #1094
# Calling for doc #1095
# Calling for doc #1095
# Calling for doc #1096
# Calling for doc #1097
# Calling for doc #1098
# Calling for doc #1099
# Calling for doc #1100
# Calling for doc #1101
# Calling for doc #1102
# Calling for doc #1103
# Calling for doc #1104
# Calling for doc #1105
# Calling for doc #1105
# Calling for doc #1106
# Calling for doc #1107
# Calling for doc #1107
# Calling for doc #1108
# Calling for doc #1109
# Calling for doc #1110
# Calling for doc #1111
# Calling for doc #1112
# Calling for doc #1113
# Calling for doc #1114
# Calling for doc #1115
# Calling for doc #1116
# Calling for doc #1117
# Calling for doc #1118
# Calling for doc #1119
# Calling for doc #1119
# Calling for doc #1120
# Calling for doc #1121
# Calling for doc #1121
# Calling for doc #1121
# Calling for doc #1121
# Calling for doc #1122
# Calling for doc #1123
# Calling for doc #1124
# Calling for doc #1125
# Calling for doc #1126
# Calling for doc #1127
# Calling for doc #1128
# Calling for doc #1129
# Calling for doc #1130
# Calling for doc #1131
# Calling for doc #1131
# Calling for doc #1131
# Calling for doc #1131
# Calling for doc #1131
# Calling for doc #1132
# Calling for doc #1133
# Calling for doc #1134
# Calling for doc #1134
# Calling for doc #1135
# Calling for doc #1135
# Calling for doc #1136
# Calling for doc #1137
# Calling for doc #1138
# Calling for doc #1139
# Calling for doc #1140
# Calling for doc #1141
# Calling for doc #1142
# Calling for doc #1143
# Calling for doc #1144
# Calling for doc #1145
# Calling for doc #1146
# Calling for doc #1147
# Calling for doc #1148
# Calling for doc #1149
# Calling for doc #1150
# Calling for doc #1151
# Calling for doc #1152
# Calling for doc #1152
# Calling for doc #1152
# Calling for doc #1153
# Calling for doc #1154
# Calling for doc #1155
# Calling for doc #1155
# Calling for doc #1156
# Calling for doc #1157
# Calling for doc #1157
# Calling for doc #1157
# Calling for doc #1157
# Calling for doc #1158
# Calling for doc #1159
# Calling for doc #1160
# Calling for doc #1160
# Calling for doc #1161
# Calling for doc #1161
# Calling for doc #1162
# Calling for doc #1163
# Calling for doc #1164
# Calling for doc #1165
# Calling for doc #1165
# Calling for doc #1165
# Calling for doc #1165
# Calling for doc #1165
# Calling for doc #1166
# Calling for doc #1167
# Calling for doc #1167
# Calling for doc #1168
# Calling for doc #1169
# Calling for doc #1170
# Calling for doc #1171
# Calling for doc #1172
# Calling for doc #1173
# Calling for doc #1174
# Calling for doc #1175
# Calling for doc #1176
# Calling for doc #1177
# Calling for doc #1178
# Calling for doc #1178
# Calling for doc #1178
# Calling for doc #1178
# Calling for doc #1178
# Calling for doc #1179
# Calling for doc #1179
# Calling for doc #1180
# Calling for doc #1181
# Calling for doc #1182
# Calling for doc #1183
# Calling for doc #1184
# Calling for doc #1185
# Calling for doc #1185
# Calling for doc #1186
# Calling for doc #1186
# Calling for doc #1186
# Calling for doc #1187
# Calling for doc #1188
# Calling for doc #1188
# Calling for doc #1189
# Calling for doc #1190
# Calling for doc #1191
# Calling for doc #1192
# Calling for doc #1193
# Calling for doc #1194
# Calling for doc #1194
# Calling for doc #1194
# Calling for doc #1194
# Calling for doc #1195
# Calling for doc #1196
# Calling for doc #1197
# Calling for doc #1197
# Calling for doc #1197
# Calling for doc #1197
# Calling for doc #1197
# Calling for doc #1198
# Calling for doc #1199
# Calling for doc #1200
# Calling for doc #1201
# Calling for doc #1202
# Calling for doc #1203
# Calling for doc #1204
# Calling for doc #1205
# Calling for doc #1206
# Calling for doc #1207
# Calling for doc #1207
# Calling for doc #1208
# Calling for doc #1209
# Calling for doc #1210
# Calling for doc #1211
# Calling for doc #1212
# Calling for doc #1213
# Calling for doc #1214
# Calling for doc #1215
# Calling for doc #1216
# Calling for doc #1217
# Calling for doc #1218
# Calling for doc #1218
# Calling for doc #1218
# Calling for doc #1219
# Calling for doc #1220
# Calling for doc #1221
# Calling for doc #1222
# Calling for doc #1223
# Calling for doc #1224
# Calling for doc #1225
# Calling for doc #1226
# Calling for doc #1227
# Calling for doc #1228
# Calling for doc #1228
# Calling for doc #1228
# Calling for doc #1229
# Calling for doc #1230
# Calling for doc #1230
# Calling for doc #1231
# Calling for doc #1232
# Calling for doc #1232
# Calling for doc #1232
# Calling for doc #1232
# Calling for doc #1233
# Calling for doc #1234
# Calling for doc #1234
# Calling for doc #1235
# Calling for doc #1235
# Calling for doc #1235
# Calling for doc #1236
# Calling for doc #1236
# Calling for doc #1237
# Calling for doc #1238
# Calling for doc #1239
# Calling for doc #1240
# Calling for doc #1241
# Calling for doc #1241
# Calling for doc #1242
# Calling for doc #1243
# Calling for doc #1244
# Calling for doc #1245
# Calling for doc #1246
# Calling for doc #1246
# Calling for doc #1246
# Calling for doc #1246
# Calling for doc #1246
# Calling for doc #1246
# Calling for doc #1246
# Calling for doc #1247
# Calling for doc #1248
# Calling for doc #1249
# Calling for doc #1250
# Calling for doc #1251
# Calling for doc #1252
# Calling for doc #1253
# Calling for doc #1254
# Calling for doc #1255
# Calling for doc #1255
# Calling for doc #1256
# Calling for doc #1257
# Calling for doc #1258
# Calling for doc #1259
# Calling for doc #1260
# Calling for doc #1261
# Calling for doc #1262
# Calling for doc #1263
# Calling for doc #1264
# Calling for doc #1264
# Calling for doc #1264
# Calling for doc #1265
# Calling for doc #1266
# Calling for doc #1267
# Calling for doc #1268
# Calling for doc #1268
# Calling for doc #1269
# Calling for doc #1270
# Calling for doc #1271
# Calling for doc #1272
# Calling for doc #1273
# Calling for doc #1274
# Calling for doc #1275
# Calling for doc #1276
# Calling for doc #1277
# Calling for doc #1278
# Calling for doc #1279
# Calling for doc #1280
# Calling for doc #1281
# Calling for doc #1282
# Calling for doc #1282
# Calling for doc #1283
# Calling for doc #1284
# Calling for doc #1285
# Calling for doc #1285
# Calling for doc #1286
# Calling for doc #1287
# Calling for doc #1288
# Calling for doc #1289
# Calling for doc #1290
# Calling for doc #1291
# Calling for doc #1292
# Calling for doc #1292
# Calling for doc #1293
# Calling for doc #1293
# Calling for doc #1294
# Calling for doc #1295
# Calling for doc #1296
# Calling for doc #1297
# Calling for doc #1298
# Calling for doc #1299
# Calling for doc #1300
# Calling for doc #1300
# Calling for doc #1301
# Calling for doc #1301
# Calling for doc #1302
# Calling for doc #1303
# Calling for doc #1303
# Calling for doc #1304
# Calling for doc #1304
# Calling for doc #1305
# Calling for doc #1306
# Calling for doc #1307
# Calling for doc #1307
# Calling for doc #1308
# Calling for doc #1309
# Calling for doc #1310
# Calling for doc #1311
# Calling for doc #1312
# Calling for doc #1313
# Calling for doc #1314
# Calling for doc #1315
# Calling for doc #1316
# Calling for doc #1317
# Calling for doc #1318
# Calling for doc #1319
# Calling for doc #1319
# Calling for doc #1319
# Calling for doc #1320
# Calling for doc #1321
# Calling for doc #1322
# Calling for doc #1323
# Calling for doc #1324
# Calling for doc #1325
# Calling for doc #1326
# Calling for doc #1326
# Calling for doc #1326
# Calling for doc #1326
# Calling for doc #1326
# Calling for doc #1326
# Calling for doc #1326
# Calling for doc #1326
# Calling for doc #1326
# Calling for doc #1326
# Calling for doc #1326
# Calling for doc #1326
# Calling for doc #1326
# Calling for doc #1326
# Calling for doc #1326
# Calling for doc #1326
# Calling for doc #1326
# Calling for doc #1326
# Calling for doc #1326
# Calling for doc #1326
# Calling for doc #1326
# Calling for doc #1326
# Calling for doc #1326
# Calling for doc #1326
# Calling for doc #1326
# Calling for doc #1326
# Calling for doc #1327
# Calling for doc #1327
# Calling for doc #1327
# Calling for doc #1328
# Calling for doc #1329
# Calling for doc #1329
# Calling for doc #1329
# Calling for doc #1330
# Calling for doc #1331
# Calling for doc #1331
# Calling for doc #1332
# Calling for doc #1333
# Calling for doc #1333
# Calling for doc #1334
# Calling for doc #1335
# Calling for doc #1336
# Calling for doc #1337
# Calling for doc #1338
# Calling for doc #1339
# Calling for doc #1340
# Calling for doc #1341
# Calling for doc #1342
# Calling for doc #1343
# Calling for doc #1344
# Calling for doc #1345
# Calling for doc #1346
# Calling for doc #1346
# Calling for doc #1346
# Calling for doc #1346
# Calling for doc #1346
# Calling for doc #1347
# Calling for doc #1347
# Calling for doc #1347
# Calling for doc #1348
# Calling for doc #1349
# Calling for doc #1350
# Calling for doc #1351
# Calling for doc #1352
# Calling for doc #1353
# Calling for doc #1354
# Calling for doc #1355
# Calling for doc #1356
# Calling for doc #1357
# Calling for doc #1357
# Calling for doc #1358
# Calling for doc #1359
# Calling for doc #1360
# Calling for doc #1361
# Calling for doc #1362
# Calling for doc #1363
# Calling for doc #1364
# Calling for doc #1364
# Calling for doc #1365
# Calling for doc #1366
# Calling for doc #1366
# Calling for doc #1367
# Calling for doc #1368
# Calling for doc #1368
# Calling for doc #1369
# Calling for doc #1370
# Calling for doc #1370
# Calling for doc #1371
# Calling for doc #1371
# Calling for doc #1372
# Calling for doc #1373
# Calling for doc #1374
# Calling for doc #1375
# Calling for doc #1376
# Calling for doc #1377
# Calling for doc #1378
# Calling for doc #1379
# Calling for doc #1380
# Calling for doc #1381
# Calling for doc #1381
# Calling for doc #1382
# Calling for doc #1382
# Calling for doc #1382
# Calling for doc #1382
# Calling for doc #1383
# Calling for doc #1384
# Calling for doc #1384
# Calling for doc #1384
# Calling for doc #1385
# Calling for doc #1385
# Calling for doc #1385
# Calling for doc #1386
# Calling for doc #1387
# Calling for doc #1388
# Calling for doc #1389
# Calling for doc #1390
# Calling for doc #1391
# Calling for doc #1392
# Calling for doc #1393
# Calling for doc #1394
# Calling for doc #1394
# Calling for doc #1394
# Calling for doc #1394
# Calling for doc #1394
# Calling for doc #1395
# Calling for doc #1396
# Calling for doc #1397
# Calling for doc #1398
# Calling for doc #1399
# Calling for doc #1400
# Calling for doc #1400
# Calling for doc #1401
# Calling for doc #1402
# Calling for doc #1403
# Calling for doc #1404
# Calling for doc #1405
# Calling for doc #1406
# Calling for doc #1407
# Calling for doc #1408
# Calling for doc #1409
# Calling for doc #1410
# Calling for doc #1411
# Calling for doc #1412
# Calling for doc #1412
# Calling for doc #1413
# Calling for doc #1414
# Calling for doc #1414
# Calling for doc #1414
# Calling for doc #1415
# Calling for doc #1416
# Calling for doc #1417
# Calling for doc #1418
# Calling for doc #1419
# Calling for doc #1420
# Calling for doc #1420
# Calling for doc #1421
# Calling for doc #1422
# Calling for doc #1423
# Calling for doc #1424
# Calling for doc #1425
# Calling for doc #1425
# Calling for doc #1426
# Calling for doc #1427
# Calling for doc #1427
# Calling for doc #1428
# Calling for doc #1428
# Calling for doc #1429
# Calling for doc #1429
# Calling for doc #1430
# Calling for doc #1431
# Calling for doc #1431
# Calling for doc #1432
# Calling for doc #1433
# Calling for doc #1434
# Calling for doc #1434
# Calling for doc #1435
# Calling for doc #1436
# Calling for doc #1437
# Calling for doc #1438
# Calling for doc #1439
# Calling for doc #1440
# Calling for doc #1441
# Calling for doc #1442
# Calling for doc #1443
# Calling for doc #1444
# Calling for doc #1444
# Calling for doc #1445
# Calling for doc #1446
# Calling for doc #1447
# Calling for doc #1448
# Calling for doc #1448
# Calling for doc #1449
# Calling for doc #1450
# Calling for doc #1450
# Calling for doc #1451
# Calling for doc #1452
# Calling for doc #1453
# Calling for doc #1454
# Calling for doc #1455
# Calling for doc #1456
# Calling for doc #1457
# Calling for doc #1457
# Calling for doc #1457
# Calling for doc #1457
# Calling for doc #1458
# Calling for doc #1459
# Calling for doc #1459
# Calling for doc #1460
# Calling for doc #1461
# Calling for doc #1462
# Calling for doc #1463
# Calling for doc #1463
# Calling for doc #1464
# Calling for doc #1464
# Calling for doc #1464
# Calling for doc #1465
# Calling for doc #1466
# Calling for doc #1467
# Calling for doc #1468
# Calling for doc #1468
# Calling for doc #1468
# Calling for doc #1469
# Calling for doc #1470
# Calling for doc #1471
# Calling for doc #1471
# Calling for doc #1471
# Calling for doc #1471
# Calling for doc #1472
# Calling for doc #1473
# Calling for doc #1474
# Calling for doc #1474
# Calling for doc #1475
# Calling for doc #1476
# Calling for doc #1477
# Calling for doc #1478
# Calling for doc #1479
# Calling for doc #1480
# Calling for doc #1481
# Calling for doc #1482
# Calling for doc #1482
# Calling for doc #1482
# Calling for doc #1483
# Calling for doc #1483
# Calling for doc #1484
# Calling for doc #1484
# Calling for doc #1485
# Calling for doc #1486
# Calling for doc #1486
# Calling for doc #1486
# Calling for doc #1487
# Calling for doc #1488
# Calling for doc #1489
# Calling for doc #1490
# Calling for doc #1490
# Calling for doc #1490
# Calling for doc #1491
# Calling for doc #1492
# Calling for doc #1493
# Calling for doc #1493
# Calling for doc #1493
# Calling for doc #1493
# Calling for doc #1494
# Calling for doc #1495
# Calling for doc #1496
# Calling for doc #1497
# Calling for doc #1498
# Calling for doc #1499
# Calling for doc #1500
# Calling for doc #1500
# Calling for doc #1501
# Calling for doc #1502
# Calling for doc #1503
# Calling for doc #1504
# Calling for doc #1505
# Calling for doc #1505
# Calling for doc #1505
# Calling for doc #1505
# Calling for doc #1506
# Calling for doc #1506
# Calling for doc #1507
# Calling for doc #1508
# Calling for doc #1509
# Calling for doc #1510
# Calling for doc #1511
# Calling for doc #1512
# Calling for doc #1513
# Calling for doc #1514
# Calling for doc #1515
# Calling for doc #1515
# Calling for doc #1516
# Calling for doc #1517
# Calling for doc #1518
# Calling for doc #1519
# Calling for doc #1520
# Calling for doc #1521
# Calling for doc #1521
# Calling for doc #1522
# Calling for doc #1523
# Calling for doc #1523
# Calling for doc #1524
# Calling for doc #1525
# Calling for doc #1526
# Calling for doc #1526
# Calling for doc #1527
# Calling for doc #1528
# Calling for doc #1529
# Calling for doc #1529
# Calling for doc #1530
# Calling for doc #1531
# Calling for doc #1532
# Calling for doc #1533
# Calling for doc #1534
# Calling for doc #1535
# Calling for doc #1536
# Calling for doc #1536
# Calling for doc #1537
# Calling for doc #1537
# Calling for doc #1537
# Calling for doc #1538
# Calling for doc #1538
# Calling for doc #1539
# Calling for doc #1540
# Calling for doc #1541
# Calling for doc #1541
# Calling for doc #1542
# Calling for doc #1543
# Calling for doc #1544
# Calling for doc #1544
# Calling for doc #1545
# Calling for doc #1546
# Calling for doc #1547
# Calling for doc #1548
# Calling for doc #1549
# Calling for doc #1550
# Calling for doc #1551
# Calling for doc #1552
# Calling for doc #1553
# Calling for doc #1554
# Calling for doc #1555
# Calling for doc #1556
# Calling for doc #1556
# Calling for doc #1557
# Calling for doc #1558
# Calling for doc #1558
# Calling for doc #1558
# Calling for doc #1559
# Calling for doc #1560
# Calling for doc #1560
# Calling for doc #1561
# Calling for doc #1562
# Calling for doc #1562
# Calling for doc #1563
# Calling for doc #1563
# Calling for doc #1563
# Calling for doc #1564
# Calling for doc #1564
# Calling for doc #1565
# Calling for doc #1565
# Calling for doc #1566
# Calling for doc #1566
# Calling for doc #1567
# Calling for doc #1568
# Calling for doc #1569
# Calling for doc #1569
# Calling for doc #1570
# Calling for doc #1571
# Calling for doc #1571
# Calling for doc #1572
# Calling for doc #1572
# Calling for doc #1572
# Calling for doc #1573
# Calling for doc #1574
# Calling for doc #1575
# Calling for doc #1576
# Calling for doc #1577
# Calling for doc #1578
# Calling for doc #1579
# Calling for doc #1580
# Calling for doc #1581
# Calling for doc #1582
# Calling for doc #1583
# Calling for doc #1583
# Calling for doc #1584
# Calling for doc #1585
# Calling for doc #1585
# Calling for doc #1586
# Calling for doc #1587
# Calling for doc #1588
# Calling for doc #1588
# Calling for doc #1589
# Calling for doc #1590
# Calling for doc #1591
# Calling for doc #1592
# Calling for doc #1593
# Calling for doc #1593
# Calling for doc #1594
# Calling for doc #1594
# Calling for doc #1594
# Calling for doc #1595
# Calling for doc #1596
# Calling for doc #1597
# Calling for doc #1598
# Calling for doc #1599
# Calling for doc #1599
# Calling for doc #1599
# Calling for doc #1599
# Calling for doc #1600
# Calling for doc #1600
# Calling for doc #1601
# Calling for doc #1602
# Calling for doc #1603
# Calling for doc #1604
# Calling for doc #1604
# Calling for doc #1605
# Calling for doc #1606
# Calling for doc #1607
# Calling for doc #1608
# Calling for doc #1609
# Calling for doc #1609
# Calling for doc #1610
# Calling for doc #1611
# Calling for doc #1612
# Calling for doc #1613
# Calling for doc #1614
# Calling for doc #1615
# Calling for doc #1616
# Calling for doc #1616
# Calling for doc #1617
# Calling for doc #1618
# Calling for doc #1619
# Calling for doc #1619
# Calling for doc #1619
# Calling for doc #1620
# Calling for doc #1621
# Calling for doc #1622
# Calling for doc #1623
# Calling for doc #1624
# Calling for doc #1625
# Calling for doc #1626
# Calling for doc #1626
# Calling for doc #1627
# Calling for doc #1628
# Calling for doc #1629
# Calling for doc #1630
# Calling for doc #1630
# Calling for doc #1630
# Calling for doc #1630
# Calling for doc #1631
# Calling for doc #1632
# Calling for doc #1633
# Calling for doc #1634
# Calling for doc #1635
# Calling for doc #1636
# Calling for doc #1636
# Calling for doc #1637
# Calling for doc #1637
# Calling for doc #1638
# Calling for doc #1639
# Calling for doc #1640
# Calling for doc #1641
# Calling for doc #1642
# Calling for doc #1643
# Calling for doc #1644
# Calling for doc #1644
# Calling for doc #1645
# Calling for doc #1646
# Calling for doc #1647
# Calling for doc #1648
# Calling for doc #1649
# Calling for doc #1650
# Calling for doc #1651
# Calling for doc #1652
# Calling for doc #1653
# Calling for doc #1653
# Calling for doc #1654
# Calling for doc #1654
# Calling for doc #1654
# Calling for doc #1655
# Calling for doc #1656
# Calling for doc #1656
# Calling for doc #1657
# Calling for doc #1658
# Calling for doc #1659
# Calling for doc #1660
# Calling for doc #1660
# Calling for doc #1661
# Calling for doc #1662
# Calling for doc #1663
# Calling for doc #1664
# Calling for doc #1665
# Calling for doc #1666
# Calling for doc #1666
# Calling for doc #1666
# Calling for doc #1667
# Calling for doc #1668
# Calling for doc #1669
# Calling for doc #1670
# Calling for doc #1671
# Calling for doc #1671
# Calling for doc #1671
# Calling for doc #1671
# Calling for doc #1671
# Calling for doc #1672
# Calling for doc #1673
# Calling for doc #1674
# Calling for doc #1675
# Calling for doc #1676
# Calling for doc #1676
# Calling for doc #1676
# Calling for doc #1677
# Calling for doc #1677
# Calling for doc #1678
# Calling for doc #1679
# Calling for doc #1680
# Calling for doc #1680
# Calling for doc #1681
# ...
# Calling for doc #3119
# Calling for doc #3119
# Calling for doc #3120
# Calling for doc #3121
# Calling for doc #3122
# Token limit for doc #3122 exceeded, reducing the prompt size.
# Calling for doc #3122
# Token limit for doc #3122 exceeded, reducing the prompt size.
# Calling for doc #3122
# Token limit for doc #3122 exceeded, reducing the prompt size.
# Calling for doc #3122
# Token limit for doc #3122 exceeded, reducing the prompt size.
# Calling for doc #3122
# Token limit for doc #3122 exceeded, reducing the prompt size.
# Calling for doc #3122
# Token limit for doc #3122 exceeded, reducing the prompt size.
# Calling for doc #3122
# Token limit for doc #3122 exceeded, reducing the prompt size.
# Calling for doc #3122
# Token limit for doc #3122 exceeded, reducing the prompt size.
# Calling for doc #3122
# Token limit for doc #3122 exceeded, reducing the prompt size.
# Calling for doc #3122
# Token limit for doc #3122 exceeded, reducing the prompt size.
# Calling for doc #3122
# Calling for doc #3123
# Calling for doc #3124
# Calling for doc #3125
# Calling for doc #3126
# Calling for doc #3127
# Calling for doc #3128
# Calling for doc #3129
# Calling for doc #3130
# Calling for doc #3131
# Calling for doc #3132
# Calling for doc #3133
# Calling for doc #3134
# Calling for doc #3135
# Calling for doc #3136
# Calling for doc #3137
# Calling for doc #3138
# Calling for doc #3139
# Token limit for doc #3139 exceeded, reducing the prompt size.
# Calling for doc #3139
# Token limit for doc #3139 exceeded, reducing the prompt size.
# Calling for doc #3139
# Calling for doc #3140
# Calling for doc #3141
# Calling for doc #3142
# Calling for doc #3143
# Calling for doc #3144
# Calling for doc #3145
# Calling for doc #3145
# Calling for doc #3145
# Calling for doc #3146
# Calling for doc #3147
# Calling for doc #3147
# Calling for doc #3148
# Calling for doc #3149
# Calling for doc #3150
# Calling for doc #3151
# Calling for doc #3151
# Calling for doc #3152
# Calling for doc #3153
# Calling for doc #3153
# Calling for doc #3154
# Calling for doc #3155
# Calling for doc #3155
# Calling for doc #3156
# Calling for doc #3156
# Calling for doc #3157
# Calling for doc #3158
# Calling for doc #3159
# Calling for doc #3160
# Calling for doc #3161
# Calling for doc #3162
# Calling for doc #3163
# Calling for doc #3164
# Calling for doc #3165
# Calling for doc #3166
# Calling for doc #3167
# Calling for doc #3168
# Calling for doc #3169
# Calling for doc #3170
# Calling for doc #3171
# Calling for doc #3171
# Calling for doc #3171
# Calling for doc #3171
# Calling for doc #3172
# Calling for doc #3173
# Calling for doc #3174
# Calling for doc #3174
# Calling for doc #3175
# Calling for doc #3176
# Calling for doc #3177
# Calling for doc #3178
# Calling for doc #3179
# Token limit for doc #3179 exceeded, reducing the prompt size.
# Calling for doc #3179
# Token limit for doc #3179 exceeded, reducing the prompt size.
# Calling for doc #3179
# Token limit for doc #3179 exceeded, reducing the prompt size.
# Calling for doc #3179
# Token limit for doc #3179 exceeded, reducing the prompt size.
# Calling for doc #3179
# Token limit for doc #3179 exceeded, reducing the prompt size.
# Calling for doc #3179
# Token limit for doc #3179 exceeded, reducing the prompt size.
# Calling for doc #3179
# Token limit for doc #3179 exceeded, reducing the prompt size.
# Calling for doc #3179
# Calling for doc #3179
# Token limit for doc #3179 exceeded, reducing the prompt size.
# Calling for doc #3179
# Token limit for doc #3179 exceeded, reducing the prompt size.
# Calling for doc #3179
# Token limit for doc #3179 exceeded, reducing the prompt size.
# Calling for doc #3179
# Token limit for doc #3179 exceeded, reducing the prompt size.
# Calling for doc #3179
# Token limit for doc #3179 exceeded, reducing the prompt size.
# Calling for doc #3179
# Token limit for doc #3179 exceeded, reducing the prompt size.
# Calling for doc #3179
# Token limit for doc #3179 exceeded, reducing the prompt size.
# Calling for doc #3179
# Calling for doc #3180
# Calling for doc #3181
# Calling for doc #3182
# Calling for doc #3183
# Calling for doc #3183
# Calling for doc #3184
# Calling for doc #3185
# Calling for doc #3186
# Calling for doc #3187
# Calling for doc #3188
# Calling for doc #3189
# Calling for doc #3189
# Calling for doc #3190
# Calling for doc #3191
# Calling for doc #3192
# Calling for doc #3193
# Calling for doc #3194
# Calling for doc #3194
# Calling for doc #3195
# Calling for doc #3196
# Calling for doc #3197
# Calling for doc #3198
# Calling for doc #3199
# Calling for doc #3200
# Calling for doc #3201
# Calling for doc #3202
# Calling for doc #3203
# Calling for doc #3204
# Calling for doc #3205
# Calling for doc #3205
# Calling for doc #3205
# Calling for doc #3205
# Calling for doc #3206
# Calling for doc #3207
# Calling for doc #3208
# Calling for doc #3209
# Calling for doc #3210
# Token limit for doc #3210 exceeded, reducing the prompt size.
# Calling for doc #3210
# Token limit for doc #3210 exceeded, reducing the prompt size.
# Calling for doc #3210
# Token limit for doc #3210 exceeded, reducing the prompt size.
# Calling for doc #3210
# Token limit for doc #3210 exceeded, reducing the prompt size.
# Calling for doc #3210
# Token limit for doc #3210 exceeded, reducing the prompt size.
# Calling for doc #3210
# Calling for doc #3211
# Calling for doc #3212
# Calling for doc #3213
# Calling for doc #3214
# Calling for doc #3215
# Calling for doc #3215
# Calling for doc #3215
# Calling for doc #3215
# Calling for doc #3216
# Calling for doc #3217
# Calling for doc #3218
# Calling for doc #3218
# Calling for doc #3218
# Calling for doc #3218
# Calling for doc #3218
# Calling for doc #3219
# Calling for doc #3220
# Calling for doc #3221
# Calling for doc #3222
# Calling for doc #3223
# Calling for doc #3223
# Calling for doc #3223
# Calling for doc #3223
# Calling for doc #3224
# Calling for doc #3225
# Calling for doc #3226
# Calling for doc #3227
# Calling for doc #3228
# Calling for doc #3228
# Calling for doc #3229
# Calling for doc #3229
# Calling for doc #3229
# Calling for doc #3229
# Calling for doc #3229
# Calling for doc #3230
# Calling for doc #3231
# Calling for doc #3232
# Calling for doc #3233
# Calling for doc #3234
# Calling for doc #3235
# Calling for doc #3236
# Calling for doc #3237
# Calling for doc #3237
# Calling for doc #3237
# Calling for doc #3238
# Calling for doc #3239
# Calling for doc #3240
# Calling for doc #3241
# Calling for doc #3242
# Calling for doc #3243
# Calling for doc #3244
# Calling for doc #3245
# Calling for doc #3246
# Calling for doc #3246
# Calling for doc #3247
# Calling for doc #3248
# Calling for doc #3248
# Calling for doc #3249
# Calling for doc #3249
# Calling for doc #3249
# Calling for doc #3250
# Calling for doc #3251
# Calling for doc #3252
# Calling for doc #3253
# Calling for doc #3254
# Calling for doc #3255
# Calling for doc #3256
# Calling for doc #3257
# Calling for doc #3258
# Calling for doc #3259
# Calling for doc #3259
# Calling for doc #3260
# Calling for doc #3261
# Calling for doc #3261
# Calling for doc #3261
# Calling for doc #3261
# Calling for doc #3261
# Calling for doc #3261
# Calling for doc #3261
# Calling for doc #3261
# Calling for doc #3261
# Calling for doc #3262
# Calling for doc #3263
# Calling for doc #3264
# Calling for doc #3265
# Calling for doc #3265
# Calling for doc #3265
# Calling for doc #3266
# Calling for doc #3267
# Calling for doc #3268
# Calling for doc #3269
# Calling for doc #3270
# Calling for doc #3271
# Calling for doc #3272
# Calling for doc #3273
# Calling for doc #3274
# Calling for doc #3274
# Calling for doc #3275
# Calling for doc #3276
# Calling for doc #3277
# Calling for doc #3278
# Calling for doc #3278
# Calling for doc #3279
# Calling for doc #3280
# Calling for doc #3281
# Calling for doc #3282
# Calling for doc #3283
# Calling for doc #3284
# Calling for doc #3285
# Calling for doc #3286
# Calling for doc #3287
# Calling for doc #3287
# Calling for doc #3287
# Calling for doc #3288
# Calling for doc #3289
# Calling for doc #3290
# Calling for doc #3291
# Calling for doc #3292
# Calling for doc #3292
# Calling for doc #3293
# Calling for doc #3294
# Calling for doc #3295
# Calling for doc #3295
# Calling for doc #3295
# Calling for doc #3296
# Calling for doc #3296
# Calling for doc #3296
# Calling for doc #3296
# Calling for doc #3296
# Calling for doc #3297
# Calling for doc #3298
# Calling for doc #3299
# Calling for doc #3300
# Calling for doc #3301
# Calling for doc #3302
# Calling for doc #3302
# Calling for doc #3303
# Calling for doc #3304
# Calling for doc #3305
# Calling for doc #3306
# Calling for doc #3307
# Calling for doc #3308
# Calling for doc #3309
# Calling for doc #3310
# Calling for doc #3311
# Calling for doc #3312
# Calling for doc #3313
# Calling for doc #3314
# Calling for doc #3315
# Calling for doc #3316
# Calling for doc #3317
# Calling for doc #3318
# Calling for doc #3318
# Calling for doc #3319
# Calling for doc #3320
# Calling for doc #3321
# Calling for doc #3322
# Calling for doc #3323
# Calling for doc #3324
# Calling for doc #3325
# Calling for doc #3326
# Calling for doc #3327
# Calling for doc #3328
# Calling for doc #3329
# Calling for doc #3330
# Calling for doc #3331
# Calling for doc #3332
# Calling for doc #3333
# Calling for doc #3334
# Calling for doc #3335
# Calling for doc #3336
# Calling for doc #3336
# Calling for doc #3336
# Calling for doc #3337
# Calling for doc #3338
# Calling for doc #3339
# Calling for doc #3339
# Calling for doc #3339
# Calling for doc #3340
# Calling for doc #3341
# Calling for doc #3342
# Calling for doc #3343
# Calling for doc #3344
# Calling for doc #3345
# Calling for doc #3346
# Token limit for doc #3346 exceeded, reducing the prompt size.
# Calling for doc #3346
# Token limit for doc #3346 exceeded, reducing the prompt size.
# Calling for doc #3346
# Token limit for doc #3346 exceeded, reducing the prompt size.
# Calling for doc #3346
# Token limit for doc #3346 exceeded, reducing the prompt size.
# Calling for doc #3346
# Token limit for doc #3346 exceeded, reducing the prompt size.
# Calling for doc #3346
# Token limit for doc #3346 exceeded, reducing the prompt size.
# Calling for doc #3346
# Token limit for doc #3346 exceeded, reducing the prompt size.
# Calling for doc #3346
# Token limit for doc #3346 exceeded, reducing the prompt size.
# Calling for doc #3346
# Token limit for doc #3346 exceeded, reducing the prompt size.
# Calling for doc #3346
# Token limit for doc #3346 exceeded, reducing the prompt size.
# Calling for doc #3346
# Token limit for doc #3346 exceeded, reducing the prompt size.
# Calling for doc #3346
# Token limit for doc #3346 exceeded, reducing the prompt size.
# Calling for doc #3346
# Token limit for doc #3346 exceeded, reducing the prompt size.
# Calling for doc #3346
# Token limit for doc #3346 exceeded, reducing the prompt size.
# Calling for doc #3346
# Calling for doc #3347
# Token limit for doc #3347 exceeded, reducing the prompt size.
# Calling for doc #3347
# Token limit for doc #3347 exceeded, reducing the prompt size.
# Calling for doc #3347
# Token limit for doc #3347 exceeded, reducing the prompt size.
# Calling for doc #3347
# Token limit for doc #3347 exceeded, reducing the prompt size.
# Calling for doc #3347
# Token limit for doc #3347 exceeded, reducing the prompt size.
# Calling for doc #3347
# Token limit for doc #3347 exceeded, reducing the prompt size.
# Calling for doc #3347
# Token limit for doc #3347 exceeded, reducing the prompt size.
# Calling for doc #3347
# Token limit for doc #3347 exceeded, reducing the prompt size.
# Calling for doc #3347
# Calling for doc #3348
# Calling for doc #3349
# Calling for doc #3350
# Calling for doc #3351
# Calling for doc #3352
# Calling for doc #3353
# Calling for doc #3354
# Calling for doc #3354
# Calling for doc #3355
# Calling for doc #3355
# Calling for doc #3355
# Calling for doc #3355
# Calling for doc #3355
# Calling for doc #3355
# Calling for doc #3355
# Calling for doc #3356
# Calling for doc #3357
# Calling for doc #3357
# Calling for doc #3358
# Calling for doc #3359
# Calling for doc #3360
# Calling for doc #3361
# Calling for doc #3362
# Calling for doc #3363
# Calling for doc #3364
# Calling for doc #3365
# Calling for doc #3366
# Calling for doc #3367
# Calling for doc #3367
# Calling for doc #3368
# Calling for doc #3368
# Calling for doc #3369
# Calling for doc #3370
# Calling for doc #3371
# Calling for doc #3372
# Calling for doc #3373
# Calling for doc #3374
# Calling for doc #3375
# Calling for doc #3376
# Calling for doc #3377
# Calling for doc #3377
# Calling for doc #3378
# Calling for doc #3379
# Calling for doc #3379
# Calling for doc #3380
# Calling for doc #3380
# Calling for doc #3381
# Calling for doc #3381
# Calling for doc #3381
# Calling for doc #3382
# Calling for doc #3383
# Calling for doc #3384
# Calling for doc #3385
# Calling for doc #3385
# Calling for doc #3385
# Calling for doc #3386
# Calling for doc #3387
# Calling for doc #3388
# Calling for doc #3389
# Calling for doc #3390
# Calling for doc #3391
# Calling for doc #3392
# Calling for doc #3393
# Calling for doc #3394
# Calling for doc #3395
# Calling for doc #3396
# Calling for doc #3396
# Calling for doc #3396
# Calling for doc #3397
# Calling for doc #3398
# Calling for doc #3399
# Calling for doc #3399
# Calling for doc #3400
# Calling for doc #3401
# Calling for doc #3402
# Calling for doc #3403
# Calling for doc #3403
# Calling for doc #3403
# Calling for doc #3403
# Calling for doc #3403
# Calling for doc #3403
# Calling for doc #3403
# Calling for doc #3403
# Calling for doc #3403
# Calling for doc #3403
# Calling for doc #3403
# Calling for doc #3403
# Calling for doc #3403
# Calling for doc #3403
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3404
# Calling for doc #3405
# Calling for doc #3405
# Calling for doc #3405
# Calling for doc #3405
# Calling for doc #3405
# Calling for doc #3405
# Calling for doc #3405
# Calling for doc #3405
# Calling for doc #3405
# Calling for doc #3405
# Calling for doc #3405
# Calling for doc #3405
# Calling for doc #3405
# Calling for doc #3405
# Calling for doc #3405
# Calling for doc #3405
# Calling for doc #3405
# Calling for doc #3406
# Calling for doc #3407
# Calling for doc #3408
# Calling for doc #3409
# Calling for doc #3410
# Calling for doc #3411
# Calling for doc #3412
# Calling for doc #3413
# Calling for doc #3414
# Calling for doc #3415
# Calling for doc #3415
# Calling for doc #3415
# Calling for doc #3416
# Calling for doc #3417
# Calling for doc #3417
# Calling for doc #3417
# Calling for doc #3417
# Calling for doc #3417
# Calling for doc #3417
# Calling for doc #3417
# Calling for doc #3417
# Calling for doc #3417
# Calling for doc #3418
# Calling for doc #3419
# Calling for doc #3420
# Calling for doc #3421
# Calling for doc #3422
# Calling for doc #3423
# Calling for doc #3424
# Calling for doc #3424
# Calling for doc #3425
# Calling for doc #3426
# Calling for doc #3427
# Calling for doc #3428
# Calling for doc #3429
# Calling for doc #3429
# Calling for doc #3430
# Calling for doc #3431
# Calling for doc #3431
# Calling for doc #3432
# Calling for doc #3432
# Calling for doc #3433
# Calling for doc #3433
# Calling for doc #3434
# Calling for doc #3434
# Calling for doc #3435
# Calling for doc #3436
# Calling for doc #3437
# Calling for doc #3438
# Calling for doc #3439
# Calling for doc #3440
# Calling for doc #3441
# Calling for doc #3441
# Calling for doc #3442
# Calling for doc #3443
# Calling for doc #3444
# Calling for doc #3445
# Calling for doc #3446
# Calling for doc #3446
# Calling for doc #3447
# Calling for doc #3448
# Calling for doc #3448
# Calling for doc #3449
# Calling for doc #3450
# Calling for doc #3451
# Calling for doc #3451
# Calling for doc #3451
# Calling for doc #3451
# Calling for doc #3451
# Calling for doc #3451
# Calling for doc #3451
# Calling for doc #3452
# Calling for doc #3453
# Calling for doc #3454
# Calling for doc #3455
# Calling for doc #3456
# Calling for doc #3457
# Calling for doc #3458
# Calling for doc #3459
# Calling for doc #3460
# Calling for doc #3460
# Calling for doc #3461
# Calling for doc #3462
# Calling for doc #3463
# Calling for doc #3464

# %%
to_rerun['topics'] = good_enough

# %%
pd.concat([to_accept, to_rerun])[['topics', 'body_clean']].to_csv("gcn_with_topics.csv", index=True)
